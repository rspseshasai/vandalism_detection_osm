# %%
from scipy.special import linestyle
# from scipy.special import style
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1. Data Loading Visualization

# %%
import pandas as pd

from config import VISUALIZATION_DATA_PATH

# Load saved data sample from data loading step
data_loading_sample_path = VISUALIZATION_DATA_PATH['data_loading']
changeset_df = pd.read_parquet(data_loading_sample_path)

# print("Summary statistics of the dataset:")
# display(changeset_df.describe())

print("Distribution of target variable (vandalism):")
vandalism_counts = changeset_df['label'].value_counts()
display(vandalism_counts)

# Visualize the data
print("\nSample of loaded changeset data:")
display(changeset_df.head())

# Plot distribution of target variable
# vandalism_counts.plot(kind='bar', title='Vandalism Distribution', xlabel='Vandalism', ylabel='Count')
# Out:
# Distribution of target variable (vandalism):
# label
# False    58
# True     42
# Name: count, dtype: int64
# Sample of loaded changeset data:
#    changeset_id                created_at                 closed_at  \
# 0      19739784 2014-01-01 00:16:15+00:00 2014-01-01 00:16:17+00:00
# 1      19739822 2014-01-01 00:21:49+00:00 2014-01-01 00:21:51+00:00
# 2      19740673 2014-01-01 03:44:23+00:00 2014-01-01 03:44:25+00:00
# 3      19740747 2014-01-01 04:12:07+00:00 2014-01-01 04:12:09+00:00
# 4      19740824 2014-01-01 04:36:01+00:00 2014-01-01 04:36:08+00:00
#
#           user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  bryanpiczon   688302            3  10.376628  123.400400  10.498390
# 1  bryanpiczon   688302           13  10.376457  123.633181  10.390640
# 2  bryanpiczon   688302           21   9.749016  124.004176  10.410474
# 3  bryanpiczon   688302           10   9.783770  125.079765  10.766378
# ...

# %% [markdown]
# ### 2. Feature Engineering Visualization

# %%
# Load saved data sample from feature engineering step
feature_engineering_sample_path = VISUALIZATION_DATA_PATH['feature_engineering']
features_df = pd.read_parquet(feature_engineering_sample_path)

# print("Summary statistics of the features:")
# display(features_df.describe())
# print("")

# Visualize the features
print("Sample of extracted features:")
display(features_df.head())
# Out:
# Sample of extracted features:
#    changeset_id                created_at                 closed_at  \
# 0      19739784 2014-01-01 00:16:15+00:00 2014-01-01 00:16:17+00:00
# 1      19739822 2014-01-01 00:21:49+00:00 2014-01-01 00:21:51+00:00
# 2      19740673 2014-01-01 03:44:23+00:00 2014-01-01 03:44:25+00:00
# 3      19740747 2014-01-01 04:12:07+00:00 2014-01-01 04:12:09+00:00
# 4      19740824 2014-01-01 04:36:01+00:00 2014-01-01 04:36:08+00:00
#
#           user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  bryanpiczon   688302            3  10.376628  123.400400  10.498390
# 1  bryanpiczon   688302           13  10.376457  123.633181  10.390640
# 2  bryanpiczon   688302           21   9.749016  124.004176  10.410474
# 3  bryanpiczon   688302           10   9.783770  125.079765  10.766378
# 4  bryanpiczon   688302           13   9.796782  125.077679  10.712891
#
#       max_lon  ... no_relations no_creates  no_modifications  no_deletions  \
# ...

# %% [markdown]
# ### 3. Preprocessing Visualization

# %%
# Load saved data samples from preprocessing step
preprocessing_X_sample_path = VISUALIZATION_DATA_PATH['preprocessing_X']
preprocessing_y_sample_path = VISUALIZATION_DATA_PATH['preprocessing_y']

X_encoded = pd.read_parquet(preprocessing_X_sample_path)
y = pd.read_parquet(preprocessing_y_sample_path)

# Visualize the preprocessed features
print("Sample of preprocessed feature data (X):")
display(X_encoded.head())

print("\nSample of preprocessed target data (y):")
display(y.head())

# Check class imbalance in target data
class_distribution = y.value_counts()
print("\nDistribution of target variable (preprocessed):")
display(class_distribution)

# Plot class distribution
# class_distribution.plot(kind='bar', title='Class Distribution', xlabel='Class', ylabel='Count')
#
# Out:
# Sample of preprocessed feature data (X):
#    changeset_id     closed_at  user_id  num_changes    min_lat     min_lon  \
# 0      19739784  1.388535e+09   688302            3  10.376628  123.400400
# 1      19739822  1.388536e+09   688302           13  10.376457  123.633181
# 2      19740673  1.388548e+09   688302           21   9.749016  124.004176
# 3      19740747  1.388550e+09   688302           10   9.783770  125.079765
# 4      19740824  1.388551e+09   688302           13   9.796782  125.077679
#
#      max_lat     max_lon  no_nodes  no_ways  ...  \
# 0  10.498390  123.635174         1        2  ...
# 1  10.390640  123.640732        10        3  ...
# 2  10.410474  125.187905        17        4  ...
# 3  10.766378  125.929561         8        2  ...
# 4  10.712891  125.838949        11        2  ...
#
#    created_by_reverter;JOSM/1.5 (14945 uk)  \
# 0                                    False
# 1                                    False
# ...

# %% [markdown]
# ### 4. Data Splitting Visualization

# %%
# Load saved data sample from data splitting step
X_train = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_train'])
X_val = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_val'])
X_test = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_test'])

# Assuming y_train, y_val, y_test are not saved; recreate splits using loaded samples if needed
# Visualize data splits
print("Sample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Print the shapes of train, validation, and test datasets (if shapes were logged previously)
print("\nShapes of datasets:")
shapes = {
    'X_train': X_train.shape,
    'X_val': X_val.shape,  # Uncomment if loaded
    'X_test': X_test.shape,  # Uncomment if loaded
    # 'y_train': y_train.shape,  # Uncomment if loaded
    # 'y_val': y_val.shape,  # Uncomment if loaded
    # 'y_test': y_test.shape,  # Uncomment if loaded
}
shapes_df = pd.DataFrame.from_dict(shapes, orient='index', columns=['Rows', 'Columns'])
display(shapes_df)
# Out:
# Sample of X_train:
#        changeset_id     closed_at  user_id  num_changes    min_lat  \
# 11177      59047176  1.526557e+09  8267951           63  35.858857
# 13889      67134459  1.549984e+09  4816089            1  21.428734
# 1596       34415596  1.443905e+09   457754           68  68.577450
# 3170       22036602  1.398839e+09    81955           14  51.549949
# 5136       45558828  1.485524e+09  5207702            7  52.219988
#
#           min_lon    max_lat     max_lon  no_nodes  no_ways  ...  \
# 11177  139.727985  35.882808  139.755059        39       24  ...
# 13889   39.829130  21.428734   39.829130         1        0  ...
# 1596    17.611793  68.712547   18.099057        67        1  ...
# 3170     6.839888  51.552965    6.847359        10        4  ...
# 5136     6.892335  52.220489    6.892875         6        1  ...
#
#        created_by_reverter;JOSM/1.5 (14945 uk)  \
# 11177                                    False
# 13889                                    False
# ...

# %% [markdown]
# ### 5. Clustering Visualization

# %%
# Notebook Code to Visualize Clustering
from src.clustering import load_clustered_data

X_train, X_val, X_test = load_clustered_data()

print("Data after adding clustering labels:")
print("\nSample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Visualize the clustering results
# visualize_clustering()
# Out:
# 2025-01-29 00:18:35 - INFO - clustering.py -- Clustered data loaded successfully.
# Data after adding clustering labels:
#
# Sample of X_train:
#        changeset_id     closed_at  user_id  num_changes    min_lat  \
# 11177      59047176  1.526557e+09  8267951           63  35.858857
# 13889      67134459  1.549984e+09  4816089            1  21.428734
# 1596       34415596  1.443905e+09   457754           68  68.577450
# 3170       22036602  1.398839e+09    81955           14  51.549949
# 5136       45558828  1.485524e+09  5207702            7  52.219988
#
#           min_lon    max_lat     max_lon  no_nodes  no_ways  ...  \
# 11177  139.727985  35.882808  139.755059        39       24  ...
# 13889   39.829130  21.428734   39.829130         1        0  ...
# 1596    17.611793  68.712547   18.099057        67        1  ...
# 3170     6.839888  51.552965    6.847359        10        4  ...
# 5136     6.892335  52.220489    6.892875         6        1  ...
#
# ...

# %% [markdown]
# ### 6. Model Evaluation Visualization

# %%
# Import evaluation functions
from evaluation import plot_confusion_matrix, plot_roc_pr_curves

# Display the confusion matrix
print("Confusion Matrix:")
plot_confusion_matrix('main')

# Plot ROC and Precision-Recall curves
print("\nROC and Precision-Recall Curves:")
plot_roc_pr_curves('main')
# Out:
# Confusion Matrix:
# ROC and Precision-Recall Curves:

# %% [markdown]
# ### 7. Bootstrapping Visualization

# %%
import config
import os
# In your Jupyter Notebook
import pandas as pd
from src.bootstrap_evaluation import plot_metric_distributions

# Load bootstrap metrics
metrics_df = pd.read_csv(os.path.join(config.BOOTSTRAP_RESULTS_DIR, 'bootstrap_test_set_metrics_all_iterations.csv'))

# Plot distributions
plot_metric_distributions(metrics_df, plot_graphs=False)
# Out:
# Bootstrap Performance Metrics on Test Set:
#       Metric      Mean   Std Dev  95% CI Lower  95% CI Upper
# 0   Accuracy  0.884316  0.004503      0.875319      0.892879
# 1  Precision  0.894338  0.006094      0.882450      0.906123
# 2     Recall  0.872356  0.006593      0.859170      0.885177
# 3   F1-score  0.883191  0.004814      0.873534      0.892522
# 4    AUC-ROC  0.949663  0.002832      0.944465      0.955148
# 5     AUC-PR  0.951936  0.003191      0.945679      0.958080

# %% [markdown]
# ## Hyper Classifier model for Changeset data

# %% [markdown]
# #### 1. Imports and Setup

# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define the paths (update these as needed)
AGGREGATED_FEATURES_PATH = VISUALIZATION_DATA_PATH['hyper_classifier_features_sample_path']
EVALUATION_RESULTS_PATH = VISUALIZATION_DATA_PATH['evaluation_results_hyper_classifier']
CONFUSION_MATRIX_PATH = VISUALIZATION_DATA_PATH['confusion_matrix_hyper_classifier']

# Helper function to set consistent plot styles
def set_plot_style():
    sns.set(style="whitegrid")
    plt.rcParams.update({"font.size": 12})

# %% [markdown]
# #### 2. Visualize Aggregated Features

# %%
# Load aggregated features
aggregated_features = pd.read_parquet(AGGREGATED_FEATURES_PATH)

# Display the first few rows
print("Aggregated Hyper Classifier Features Sample:")
aggregated_features.head()
# Out:
# Aggregated Hyper Classifier Features Sample:
#    changeset_id  num_contributions  mean_prediction  median_prediction  \
# 0      19739784                  3         0.885573           0.841576
# 1      19739822                  3         0.982906           0.976532
# 2      19740673                  6         0.990875           0.988358
# 3      19740747                  8         0.973813           0.993531
# 4      19740824                  9         0.993006           0.992664
#
#    std_prediction  min_prediction  max_prediction  quantile_25  quantile_75  \
# 0        0.081106        0.835972        0.979171     0.838774     0.910373
# 1        0.013055        0.974262        0.997924     0.975397     0.987228
# 2        0.005401        0.985704        0.998462     0.987514     0.994941
# 3        0.057893        0.830787        0.999279     0.990611     0.995459
# 4        0.002719        0.989070        0.999537     0.992664     0.992664
#
# ...

# %%
# Plot distributions of key features
set_plot_style()

# Number of contributions
plt.figure(figsize=(8, 5))
sns.histplot(aggregated_features['num_contributions'], bins=30, kde=True, color='blue')
plt.title('Distribution of Number of Contributions per Changeset')
plt.xlabel('Number of Contributions')
plt.ylabel('Frequency')
plt.show()

# Mean prediction
plt.figure(figsize=(8, 5))
sns.histplot(aggregated_features['mean_prediction'], bins=30, kde=True, color='green')
plt.title('Distribution of Mean Predictions')
plt.xlabel('Mean Prediction')
plt.ylabel('Frequency')
plt.show()

# Standard deviation of predictions
plt.figure(figsize=(8, 5))
sns.histplot(aggregated_features['std_prediction'], bins=30, kde=True, color='orange')
plt.title('Distribution of Standard Deviation of Predictions')
plt.xlabel('Standard Deviation')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### 3. Visualize Evaluation Results

# %%
# Load evaluation results
evaluation_results = pd.read_parquet(EVALUATION_RESULTS_PATH)

# Display the first few rows
print("Evaluation Results Sample:")
evaluation_results.head()
# Out:
# Evaluation Results Sample:
#    changeset_id  y_true  y_pred_hyper_classifier  y_prob_hyper_classifier
# 0      77012980    True                        1                 0.996060
# 1      70295694   False                        0                 0.000642
# 2      51030611    True                        1                 0.999667
# 3      55753908    True                        1                 0.999569
# 4      69778039   False                        0                 0.023674

# %%
plot_confusion_matrix('hyper_classifier')

# %%
# Calculate and display key metrics from evaluation results
accuracy = (evaluation_results['y_true'] == evaluation_results['y_pred_hyper_classifier']).mean()
precision = evaluation_results.query("y_pred_hyper_classifier == 1 & y_true == 1").shape[0] / evaluation_results.query("y_pred_hyper_classifier == 1").shape[0]
recall = evaluation_results.query("y_pred_hyper_classifier == 1 & y_true == 1").shape[0] / evaluation_results.query("y_true == 1").shape[0]
f1_score = 2 * (precision * recall) / (precision + recall)

print("Evaluation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Evaluation Metrics:
# Accuracy: 0.9712
# Precision: 0.9764
# Recall: 0.9669
# F1 Score: 0.9716

# %% [markdown]
# #### 4. Visualize ROC and PR Curves

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Calculate ROC Curve
fpr, tpr, _ = roc_curve(evaluation_results['y_true'], evaluation_results['y_prob_hyper_classifier'])

# Plot ROC Curve
plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(evaluation_results['y_true'], evaluation_results['y_prob_hyper_classifier']):.4f}")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

# Calculate Precision-Recall Curve
precision, recall, _ = precision_recall_curve(evaluation_results['y_true'], evaluation_results['y_prob_hyper_classifier'])

# Plot Precision-Recall Curve
plt.figure(figsize=(8, 5))
plt.plot(recall, precision, label=f"Avg Precision = {average_precision_score(evaluation_results['y_true'], evaluation_results['y_prob_hyper_classifier']):.4f}")
plt.title("Precision-Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend(loc="lower left")
plt.grid()
plt.show()

# %% [markdown]
# ## Meta Classifier model for Changeset Data

# %% [markdown]
# #### 1. Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    roc_curve, auc, confusion_matrix, precision_recall_curve,
    classification_report
)

# %% [markdown]
# #### 2. Load Results

# %%
# Load the results
results_df = pd.read_csv(VISUALIZATION_DATA_PATH['evaluation_results_meta_classifier'])

# %% [markdown]
# #### 3. Print Performance Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

def calculate_metrics(y_true, y_pred, y_prob):
    metrics = {}
    metrics['Accuracy'] = accuracy_score(y_true, y_pred)
    metrics['Precision'] = precision_score(y_true, y_pred, zero_division=0)
    metrics['Recall'] = recall_score(y_true, y_pred, zero_division=0)
    metrics['F1-Score'] = f1_score(y_true, y_pred, zero_division=0)
    metrics['AUC-ROC'] = roc_auc_score(y_true, y_prob)
    return metrics

# Calculate metrics for each model
metrics_main = calculate_metrics(
    results_df['y_true'],
    results_df['y_pred_main_model'],
    results_df['y_prob_main_model']
)

metrics_hyper = calculate_metrics(
    results_df['y_true'],
    results_df['y_pred_hyper_classifier'],
    results_df['y_prob_hyper_classifier']
)

metrics_meta = calculate_metrics(
    results_df['y_true'],
    results_df['y_pred_meta_classifier'],
    results_df['y_prob_meta_classifier']
)

# Create a DataFrame for metrics
metrics_df = pd.DataFrame({
    'Main Model': metrics_main,
    'Hyper-Classifier Model': metrics_hyper,
    'Meta-Classifier Model': metrics_meta
})

# Transpose for better display
metrics_df = metrics_df.transpose()

# Display the metrics table
print("Performance Metrics:")
display(metrics_df.style.format("{:.4f}"))
# Out:
# Performance Metrics:
# <style type="text/css">
# </style>
# <table id="T_b6ae3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6ae3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b6ae3_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_b6ae3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b6ae3_level0_col3" class="col_heading level0 col3" >F1-Score</th>
#       <th id="T_b6ae3_level0_col4" class="col_heading level0 col4" >AUC-ROC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6ae3_level0_row0" class="row_heading level0 row0" >Main Model</th>
#       <td id="T_b6ae3_row0_col0" class="data row0 col0" >0.8715</td>
#       <td id="T_b6ae3_row0_col1" class="data row0 col1" >0.8713</td>
#       <td id="T_b6ae3_row0_col2" class="data row0 col2" >0.8773</td>
#       <td id="T_b6ae3_row0_col3" class="data row0 col3" >0.8743</td>
# ...

# %% [markdown]
# #### 4. Plot ROC Curves

# %%
# Plot ROC Curves
plt.figure(figsize=(10, 8))

# Main Model
fpr_main, tpr_main, _ = roc_curve(results_df['y_true'], results_df['y_prob_main_model'])
roc_auc_main = auc(fpr_main, tpr_main)
plt.plot(fpr_main, tpr_main, label=f'Baseline Changeset Pipeline (AUC = {roc_auc_main:.4f})')

# Hyper-Classifier Model
fpr_hyper, tpr_hyper, _ = roc_curve(results_df['y_true'], results_df['y_prob_hyper_classifier'])
roc_auc_hyper = auc(fpr_hyper, tpr_hyper)
plt.plot(fpr_hyper, tpr_hyper, linestyle="--" ,label=f'Hyper-Classifier Model (AUC = {roc_auc_hyper:.4f})')

# Meta-Classifier Model
fpr_meta, tpr_meta, _ = roc_curve(results_df['y_true'], results_df['y_prob_meta_classifier'])
roc_auc_meta = auc(fpr_meta, tpr_meta)
plt.plot(fpr_meta, tpr_meta,  linestyle="--" ,label=f'Meta-Classifier Model (AUC = {roc_auc_meta:.4f})')

# Plot settings
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curves', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# #### 5. Plot Confusion Matrices

# %%
from sklearn.metrics import ConfusionMatrixDisplay

models = ['Main Model', 'Hyper-Classifier Model', 'Meta-Classifier Model']
predictions = [
    ('Main Model', results_df['y_pred_main_model']),
    ('Hyper-Classifier Model', results_df['y_pred_hyper_classifier']),
    ('Meta-Classifier Model', results_df['y_pred_meta_classifier'])
]

for model_name, y_pred in predictions:
    cm = confusion_matrix(results_df['y_true'], y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Non-Vandalism', 'Vandalism'])
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Confusion Matrix: {model_name}', fontsize=16)
    plt.xlabel('Predicted Label', fontsize=14)
    plt.ylabel('True Label', fontsize=14)
    plt.show()

# %% [markdown]
# #### 6. Plot Precision-Recall Curves

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# Plot Precision-Recall Curves
plt.figure(figsize=(10, 8))

# Main Model (Baseline with dotted line)
precision_main, recall_main, _ = precision_recall_curve(results_df['y_true'], results_df['y_prob_main_model'])
plt.plot(recall_main, precision_main, linestyle=':', color='blue', label='Baseline Changeset Pipeline')

# Hyper-Classifier Model (Hyper-Classifier with dotted line)
precision_hyper, recall_hyper, _ = precision_recall_curve(results_df['y_true'], results_df['y_prob_hyper_classifier'])
plt.plot(recall_hyper, precision_hyper, linestyle='--', color='green', label='Hyper-Classifier Model')

# Meta-Classifier Model (Solid line for emphasis)
precision_meta, recall_meta, _ = precision_recall_curve(results_df['y_true'], results_df['y_prob_meta_classifier'])
plt.plot(recall_meta, precision_meta, linestyle='--', linewidth=0.8, color='red', label='Meta-Classifier Model')

# Plot settings
plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.title('Precision-Recall Curves', fontsize=16)
plt.legend(loc='lower left', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)  # Add a grid for better readability
plt.tight_layout()

# Ensure the plot is displayed in Jupyter Notebook
plt.show()

# %% [markdown]
# #### 7. Classification Reports

# %%
# Classification Reports
for model_name, y_pred in predictions:
    print(f"Classification Report for {model_name}:")
    report = classification_report(results_df['y_true'], y_pred, target_names=['Non-Vandalism', 'Vandalism'], zero_division=0)
    print(report)
    print("-" * 80)
# Out:
# Classification Report for Main Model:
#                precision    recall  f1-score   support
#
# Non-Vandalism       0.87      0.87      0.87      1953
#     Vandalism       0.87      0.88      0.87      2030
#
#      accuracy                           0.87      3983
#     macro avg       0.87      0.87      0.87      3983
#  weighted avg       0.87      0.87      0.87      3983
#
# --------------------------------------------------------------------------------
# Classification Report for Hyper-Classifier Model:
#                precision    recall  f1-score   support
#
# Non-Vandalism       0.97      0.98      0.98      1953
#     Vandalism       0.98      0.97      0.98      2030
#
#      accuracy                           0.98      3983
#     macro avg       0.98      0.98      0.98      3983
#  weighted avg       0.98      0.98      0.98      3983
#
# --------------------------------------------------------------------------------
# ...
