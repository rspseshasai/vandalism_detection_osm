# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1. Data Loading Visualization

# %%
import pandas as pd

from config import VISUALIZATION_DATA_PATH

# Load saved data sample from data loading step
data_loading_sample_path = VISUALIZATION_DATA_PATH['data_loading']
changeset_df = pd.read_parquet(data_loading_sample_path)

# print("Summary statistics of the dataset:")
# display(changeset_df.describe())

print("Distribution of target variable (vandalism):")
vandalism_counts = changeset_df['label'].value_counts()
display(vandalism_counts)

# Visualize the data
print("\nSample of loaded changeset data:")
display(changeset_df.head())

# Plot distribution of target variable
# vandalism_counts.plot(kind='bar', title='Vandalism Distribution', xlabel='Vandalism', ylabel='Count')
# Out:
# Distribution of target variable (vandalism):
# label
# False    58
# True     42
# Name: count, dtype: int64
# Sample of loaded changeset data:
#    changeset_id                created_at                 closed_at  \
# 0      19739784 2014-01-01 00:16:15+00:00 2014-01-01 00:16:17+00:00
# 1      19739822 2014-01-01 00:21:49+00:00 2014-01-01 00:21:51+00:00
# 2      19740673 2014-01-01 03:44:23+00:00 2014-01-01 03:44:25+00:00
# 3      19740747 2014-01-01 04:12:07+00:00 2014-01-01 04:12:09+00:00
# 4      19740824 2014-01-01 04:36:01+00:00 2014-01-01 04:36:08+00:00
#
#           user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  bryanpiczon   688302            3  10.376628  123.400400  10.498390
# 1  bryanpiczon   688302           13  10.376457  123.633181  10.390640
# 2  bryanpiczon   688302           21   9.749016  124.004176  10.410474
# 3  bryanpiczon   688302           10   9.783770  125.079765  10.766378
# 4  bryanpiczon   688302           13   9.796782  125.077679  10.712891
#
#       max_lon  ... label no_nodes  no_ways  no_relations  no_creates  \
# 0  123.635174  ...  True        1        2             0           1
# 1  123.640732  ...  True       10        3             0          12
# 2  125.187905  ...  True       17        4             0          21
# 3  125.929561  ...  True        8        2             0           8
# 4  125.838949  ...  True       11        2             0          12
#
#    no_modifications  no_deletions     uid       account_created  changes_count
# 0                 2             0  688302  2012-05-24T12:27:56Z              0
# 1                 1             0  688302  2012-05-24T12:27:56Z              0
# 2                 0             0  688302  2012-05-24T12:27:56Z              0
# 3                 2             0  688302  2012-05-24T12:27:56Z              0
# 4                 1             0  688302  2012-05-24T12:27:56Z              0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 2. Feature Engineering Visualization

# %%
# Load saved data sample from feature engineering step
feature_engineering_sample_path = VISUALIZATION_DATA_PATH['feature_engineering']
features_df = pd.read_parquet(feature_engineering_sample_path)

# print("Summary statistics of the features:")
# display(features_df.describe())
# print("")

# Visualize the features
print("Sample of extracted features:")
display(features_df.head())
# Out:
# Sample of extracted features:
#    changeset_id                created_at                 closed_at  \
# 0      19739784 2014-01-01 00:16:15+00:00 2014-01-01 00:16:17+00:00
# 1      19739822 2014-01-01 00:21:49+00:00 2014-01-01 00:21:51+00:00
# 2      19740673 2014-01-01 03:44:23+00:00 2014-01-01 03:44:25+00:00
# 3      19740747 2014-01-01 04:12:07+00:00 2014-01-01 04:12:09+00:00
# 4      19740824 2014-01-01 04:36:01+00:00 2014-01-01 04:36:08+00:00
#
#           user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  bryanpiczon   688302            3  10.376628  123.400400  10.498390
# 1  bryanpiczon   688302           13  10.376457  123.633181  10.390640
# 2  bryanpiczon   688302           21   9.749016  124.004176  10.410474
# 3  bryanpiczon   688302           10   9.783770  125.079765  10.766378
# 4  bryanpiczon   688302           13   9.796782  125.077679  10.712891
#
#       max_lon  ... no_relations no_creates  no_modifications  no_deletions  \
# 0  123.635174  ...            0          1                 2             0
# 1  123.640732  ...            0         12                 1             0
# 2  125.187905  ...            0         21                 0             0
# 3  125.929561  ...            0          8                 2             0
# 4  125.838949  ...            0         12                 1             0
#
#       uid       account_created  changes_count  centroid_x  centroid_y  \
# 0  688302  2012-05-24T12:27:56Z              0  123.517787   10.437509
# 1  688302  2012-05-24T12:27:56Z              0  123.636956   10.383549
# 2  688302  2012-05-24T12:27:56Z              0  124.596040   10.079745
# 3  688302  2012-05-24T12:27:56Z              0  125.504663   10.275074
# 4  688302  2012-05-24T12:27:56Z              0  125.458314   10.254837
#
#    changeset_comment_length
# 0                         4
# 1                         4
# 2                         4
# 3                         4
# 4                         4
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 3. Preprocessing Visualization

# %%
# Load saved data samples from preprocessing step
preprocessing_X_sample_path = VISUALIZATION_DATA_PATH['preprocessing_X']
preprocessing_y_sample_path = VISUALIZATION_DATA_PATH['preprocessing_y']

X_encoded = pd.read_parquet(preprocessing_X_sample_path)
y = pd.read_parquet(preprocessing_y_sample_path)

# Visualize the preprocessed features
print("Sample of preprocessed feature data (X):")
display(X_encoded.head())

print("\nSample of preprocessed target data (y):")
display(y.head())

# Check class imbalance in target data
class_distribution = y.value_counts()
print("\nDistribution of target variable (preprocessed):")
display(class_distribution)

# Plot class distribution
# class_distribution.plot(kind='bar', title='Class Distribution', xlabel='Class', ylabel='Count')
#
# Out:
# Sample of preprocessed feature data (X):
#       closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  1.388535e+09   688302            3  10.376628  123.400400  10.498390
# 1  1.388536e+09   688302           13  10.376457  123.633181  10.390640
# 2  1.388548e+09   688302           21   9.749016  124.004176  10.410474
# 3  1.388550e+09   688302           10   9.783770  125.079765  10.766378
# 4  1.388551e+09   688302           13   9.796782  125.077679  10.712891
#
#       max_lon  no_nodes  no_ways  no_relations  ...  \
# 0  123.635174         1        2             0  ...
# 1  123.640732        10        3             0  ...
# 2  125.187905        17        4             0  ...
# 3  125.929561         8        2             0  ...
# 4  125.838949        11        2             0  ...
#
#    created_by_reverter;JOSM/1.5 (14945 uk)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    created_by_reverter_plugin/34977;JOSM/1.5 (15031 en)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    created_by_reverter_plugin/34999;JOSM/1.5 (15155 de)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    created_by_reverter_plugin/35084;JOSM/1.5 (15492 en)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    created_by_rocketdata.io  created_by_rosemary v0.3.12  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    created_by_rosemary v0.4.4  created_by_simple_revert.py  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    created_by_streetkeysmv  created_by_upload.py v. 1
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
#
# [5 rows x 1462 columns]
# Sample of preprocessed target data (y):
#    vandalism
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# Distribution of target variable (preprocessed):
# vandalism
# False        58
# True         42
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Data Splitting Visualization

# %%
# Load saved data sample from data splitting step
X_train = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_train'])
X_val = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_val'])
X_test = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_test'])

# Assuming y_train, y_val, y_test are not saved; recreate splits using loaded samples if needed
# Visualize data splits
print("Sample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Print the shapes of train, validation, and test datasets (if shapes were logged previously)
print("\nShapes of datasets:")
shapes = {
    'X_train': X_train.shape,
    'X_val': X_val.shape,  # Uncomment if loaded
    'X_test': X_test.shape,  # Uncomment if loaded
    # 'y_train': y_train.shape,  # Uncomment if loaded
    # 'y_val': y_val.shape,  # Uncomment if loaded
    # 'y_test': y_test.shape,  # Uncomment if loaded
}
shapes_df = pd.DataFrame.from_dict(shapes, orient='index', columns=['Rows', 'Columns'])
display(shapes_df)
# Out:
# Sample of X_train:
#           closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 11177  1.526557e+09  8267951           63  35.858857  139.727985  35.882808
# 6301   1.494221e+09  4799604            1  48.080705    7.172609  48.080705
# 4871   1.484504e+09  1881751           31  -1.516536  -47.419837  -1.249818
# 6316   1.494409e+09  5624703            6  -1.179729   34.058211  -1.179440
# 3969   1.474625e+09  4326441            1  12.978510   77.589252  12.978510
#
#           max_lon  no_nodes  no_ways  no_relations  ...  \
# 11177  139.755059        39       24             0  ...
# 6301     7.172609         1        0             0  ...
# 4871   -47.186255        31        0             0  ...
# 6316    34.058367         5        1             0  ...
# 3969    77.589252         1        0             0  ...
#
#        created_by_reverter;JOSM/1.5 (14945 uk)  \
# 11177                                    False
# 6301                                     False
# 4871                                     False
# 6316                                     False
# 3969                                     False
#
#        created_by_reverter_plugin/34977;JOSM/1.5 (15031 en)  \
# 11177                                              False
# 6301                                               False
# 4871                                               False
# 6316                                               False
# 3969                                               False
#
#        created_by_reverter_plugin/34999;JOSM/1.5 (15155 de)  \
# 11177                                              False
# 6301                                               False
# 4871                                               False
# 6316                                               False
# 3969                                               False
#
#        created_by_reverter_plugin/35084;JOSM/1.5 (15492 en)  \
# 11177                                              False
# 6301                                               False
# 4871                                               False
# 6316                                               False
# 3969                                               False
#
#        created_by_rocketdata.io  created_by_rosemary v0.3.12  \
# 11177                     False                        False
# 6301                      False                        False
# 4871                      False                        False
# 6316                      False                        False
# 3969                      False                        False
#
#        created_by_rosemary v0.4.4  created_by_simple_revert.py  \
# 11177                       False                        False
# 6301                        False                        False
# 4871                        False                        False
# 6316                        False                        False
# 3969                        False                        False
#
#        created_by_streetkeysmv  created_by_upload.py v. 1
# 11177                    False                      False
# 6301                     False                      False
# 4871                     False                      False
# 6316                     False                      False
# 3969                     False                      False
#
# [5 rows x 1462 columns]
# Sample of X_val:
#           closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 10301  1.519072e+09  7642087            5  38.706349   -9.225537  38.708119
# 11872  1.532277e+09  6631989            1  44.465331   14.956754  44.465331
# 5973   1.490559e+09   136807           79  -6.216750  106.817820  -6.209371
# 676    1.429959e+09   671668            7  52.204276    8.713752  52.208481
# 13417  1.546427e+09  8689250           41  40.411696   -3.683269  40.415235
#
#           max_lon  no_nodes  no_ways  no_relations  ...  \
# 10301   -9.223939         4        1             0  ...
# 11872   14.956754         1        0             0  ...
# 5973   106.824253        74        5             0  ...
# 676      8.714885         0        4             3  ...
# 13417   -3.680589        33        8             0  ...
#
#        created_by_reverter;JOSM/1.5 (14945 uk)  \
# 10301                                    False
# 11872                                    False
# 5973                                     False
# 676                                      False
# 13417                                    False
#
#        created_by_reverter_plugin/34977;JOSM/1.5 (15031 en)  \
# 10301                                              False
# 11872                                              False
# 5973                                               False
# 676                                                False
# 13417                                              False
#
#        created_by_reverter_plugin/34999;JOSM/1.5 (15155 de)  \
# 10301                                              False
# 11872                                              False
# 5973                                               False
# 676                                                False
# 13417                                              False
#
#        created_by_reverter_plugin/35084;JOSM/1.5 (15492 en)  \
# 10301                                              False
# 11872                                              False
# 5973                                               False
# 676                                                False
# 13417                                              False
#
#        created_by_rocketdata.io  created_by_rosemary v0.3.12  \
# 10301                     False                        False
# 11872                     False                        False
# 5973                      False                        False
# 676                       False                        False
# 13417                     False                        False
#
#        created_by_rosemary v0.4.4  created_by_simple_revert.py  \
# 10301                       False                        False
# 11872                       False                        False
# 5973                        False                        False
# 676                         False                        False
# 13417                       False                        False
#
#        created_by_streetkeysmv  created_by_upload.py v. 1
# 10301                    False                      False
# 11872                    False                      False
# 5973                     False                      False
# 676                      False                      False
# 13417                    False                      False
#
# [5 rows x 1462 columns]
# Sample of X_test:
#           closed_at  user_id  num_changes    min_lat    min_lon    max_lat  \
# 3804   1.472512e+09  4491665            1  33.056209  -5.414662  33.056209
# 3947   1.474542e+09  4326441            1  12.844508  77.901588  12.844508
# 13583  1.548110e+09  9365826           46  42.458484  -6.083893  42.459887
# 1575   1.443356e+09  1782463           19  42.344855 -77.989927  42.396072
# 12803  1.540467e+09  4990369            6  52.022279   5.555816  52.022719
#
#          max_lon  no_nodes  no_ways  no_relations  ...  \
# 3804   -5.414662         1        0             0  ...
# 3947   77.901588         1        0             0  ...
# 13583  -6.064706        36        8             2  ...
# 1575  -77.945770        15        3             1  ...
# 12803   5.556632         4        2             0  ...
#
#        created_by_reverter;JOSM/1.5 (14945 uk)  \
# 3804                                     False
# 3947                                     False
# 13583                                    False
# 1575                                     False
# 12803                                    False
#
#        created_by_reverter_plugin/34977;JOSM/1.5 (15031 en)  \
# 3804                                               False
# 3947                                               False
# 13583                                              False
# 1575                                               False
# 12803                                              False
#
#        created_by_reverter_plugin/34999;JOSM/1.5 (15155 de)  \
# 3804                                               False
# 3947                                               False
# 13583                                              False
# 1575                                               False
# 12803                                              False
#
#        created_by_reverter_plugin/35084;JOSM/1.5 (15492 en)  \
# 3804                                               False
# 3947                                               False
# 13583                                              False
# 1575                                               False
# 12803                                              False
#
#        created_by_rocketdata.io  created_by_rosemary v0.3.12  \
# 3804                      False                        False
# 3947                      False                        False
# 13583                     False                        False
# 1575                      False                        False
# 12803                     False                        False
#
#        created_by_rosemary v0.4.4  created_by_simple_revert.py  \
# 3804                        False                        False
# 3947                        False                        False
# 13583                       False                        False
# 1575                        False                        False
# 12803                       False                        False
#
#        created_by_streetkeysmv  created_by_upload.py v. 1
# 3804                     False                      False
# 3947                     False                      False
# 13583                    False                      False
# 1575                     False                      False
# 12803                    False                      False
#
# [5 rows x 1462 columns]
# Shapes of datasets:
#          Rows  Columns
# X_train   100     1462
# X_val     100     1462
# X_test    100     1462

# %% [markdown]
# ### 5. Clustering Visualization

# %%
# Notebook Code to Visualize Clustering
from src.clustering import load_clustered_data

X_train, X_val, X_test = load_clustered_data()

print("Data after adding clustering labels:")
print("\nSample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Visualize the clustering results
# visualize_clustering()
# Out:
# 2024-11-27 11:23:50 - INFO - clustering.py -- Clustered data loaded successfully.
# Data after adding clustering labels:
#
# Sample of X_train:
#           closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 11177  1.526557e+09  8267951           63  35.858857  139.727985  35.882808
# 6301   1.494221e+09  4799604            1  48.080705    7.172609  48.080705
# 4871   1.484504e+09  1881751           31  -1.516536  -47.419837  -1.249818
# 6316   1.494409e+09  5624703            6  -1.179729   34.058211  -1.179440
# 3969   1.474625e+09  4326441            1  12.978510   77.589252  12.978510
#
#           max_lon  no_nodes  no_ways  no_relations  ...  \
# 11177  139.755059        39       24             0  ...
# 6301     7.172609         1        0             0  ...
# 4871   -47.186255        31        0             0  ...
# 6316    34.058367         5        1             0  ...
# 3969    77.589252         1        0             0  ...
#
#        created_by_reverter_plugin/34977;JOSM/1.5 (15031 en)  \
# 11177                                              False
# 6301                                               False
# 4871                                               False
# 6316                                               False
# 3969                                               False
#
#        created_by_reverter_plugin/34999;JOSM/1.5 (15155 de)  \
# 11177                                              False
# 6301                                               False
# 4871                                               False
# 6316                                               False
# 3969                                               False
#
#        created_by_reverter_plugin/35084;JOSM/1.5 (15492 en)  \
# 11177                                              False
# 6301                                               False
# 4871                                               False
# 6316                                               False
# 3969                                               False
#
#        created_by_rocketdata.io  created_by_rosemary v0.3.12  \
# 11177                     False                        False
# 6301                      False                        False
# 4871                      False                        False
# 6316                      False                        False
# 3969                      False                        False
#
#        created_by_rosemary v0.4.4  created_by_simple_revert.py  \
# 11177                       False                        False
# 6301                        False                        False
# 4871                        False                        False
# 6316                        False                        False
# 3969                        False                        False
#
#        created_by_streetkeysmv  created_by_upload.py v. 1  cluster_label
# 11177                    False                      False             33
# 6301                     False                      False             55
# 4871                     False                      False             74
# 6316                     False                      False             22
# 3969                     False                      False             23
#
# [5 rows x 1463 columns]
# Sample of X_val:
#           closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 10301  1.519072e+09  7642087            5  38.706349   -9.225537  38.708119
# 11872  1.532277e+09  6631989            1  44.465331   14.956754  44.465331
# 5973   1.490559e+09   136807           79  -6.216750  106.817820  -6.209371
# 676    1.429959e+09   671668            7  52.204276    8.713752  52.208481
# 13417  1.546427e+09  8689250           41  40.411696   -3.683269  40.415235
#
#           max_lon  no_nodes  no_ways  no_relations  ...  \
# 10301   -9.223939         4        1             0  ...
# 11872   14.956754         1        0             0  ...
# 5973   106.824253        74        5             0  ...
# 676      8.714885         0        4             3  ...
# 13417   -3.680589        33        8             0  ...
#
#        created_by_reverter_plugin/34977;JOSM/1.5 (15031 en)  \
# 10301                                              False
# 11872                                              False
# 5973                                               False
# 676                                                False
# 13417                                              False
#
#        created_by_reverter_plugin/34999;JOSM/1.5 (15155 de)  \
# 10301                                              False
# 11872                                              False
# 5973                                               False
# 676                                                False
# 13417                                              False
#
#        created_by_reverter_plugin/35084;JOSM/1.5 (15492 en)  \
# 10301                                              False
# 11872                                              False
# 5973                                               False
# 676                                                False
# 13417                                              False
#
#        created_by_rocketdata.io  created_by_rosemary v0.3.12  \
# 10301                     False                        False
# 11872                     False                        False
# 5973                      False                        False
# 676                       False                        False
# 13417                     False                        False
#
#        created_by_rosemary v0.4.4  created_by_simple_revert.py  \
# 10301                       False                        False
# 11872                       False                        False
# 5973                        False                        False
# 676                         False                        False
# 13417                       False                        False
#
#        created_by_streetkeysmv  created_by_upload.py v. 1  cluster_label
# 10301                    False                      False             39
# 11872                    False                      False             40
# 5973                     False                      False             51
# 676                      False                      False             46
# 13417                    False                      False              2
#
# [5 rows x 1463 columns]
# Sample of X_test:
#           closed_at  user_id  num_changes    min_lat    min_lon    max_lat  \
# 3804   1.472512e+09  4491665            1  33.056209  -5.414662  33.056209
# 3947   1.474542e+09  4326441            1  12.844508  77.901588  12.844508
# 13583  1.548110e+09  9365826           46  42.458484  -6.083893  42.459887
# 1575   1.443356e+09  1782463           19  42.344855 -77.989927  42.396072
# 12803  1.540467e+09  4990369            6  52.022279   5.555816  52.022719
#
#          max_lon  no_nodes  no_ways  no_relations  ...  \
# 3804   -5.414662         1        0             0  ...
# 3947   77.901588         1        0             0  ...
# 13583  -6.064706        36        8             2  ...
# 1575  -77.945770        15        3             1  ...
# 12803   5.556632         4        2             0  ...
#
#        created_by_reverter_plugin/34977;JOSM/1.5 (15031 en)  \
# 3804                                               False
# 3947                                               False
# 13583                                              False
# 1575                                               False
# 12803                                              False
#
#        created_by_reverter_plugin/34999;JOSM/1.5 (15155 de)  \
# 3804                                               False
# 3947                                               False
# 13583                                              False
# 1575                                               False
# 12803                                              False
#
#        created_by_reverter_plugin/35084;JOSM/1.5 (15492 en)  \
# 3804                                               False
# 3947                                               False
# 13583                                              False
# 1575                                               False
# 12803                                              False
#
#        created_by_rocketdata.io  created_by_rosemary v0.3.12  \
# 3804                      False                        False
# 3947                      False                        False
# 13583                     False                        False
# 1575                      False                        False
# 12803                     False                        False
#
#        created_by_rosemary v0.4.4  created_by_simple_revert.py  \
# 3804                        False                        False
# 3947                        False                        False
# 13583                       False                        False
# 1575                        False                        False
# 12803                       False                        False
#
#        created_by_streetkeysmv  created_by_upload.py v. 1  cluster_label
# 3804                     False                      False              2
# 3947                     False                      False             23
# 13583                    False                      False             39
# 1575                     False                      False              3
# 12803                    False                      False             46
#
# [5 rows x 1463 columns]

# %% [markdown]
# ### 6. Model Evaluation Visualization

# %%
# Import evaluation functions
from evaluation import plot_confusion_matrix, plot_roc_pr_curves

# Display the confusion matrix
print("Confusion Matrix:")
plot_confusion_matrix()

# Plot ROC and Precision-Recall curves
print("\nROC and Precision-Recall Curves:")
plot_roc_pr_curves()
# Out:
# Confusion Matrix:
# ROC and Precision-Recall Curves:

# %% [markdown]
# ### 7. Bootstrapping Visualization

# %%
import config
import os
# In your Jupyter Notebook
import pandas as pd
from src.bootstrap_evaluation import plot_metric_distributions

# Load bootstrap metrics
metrics_df = pd.read_csv(os.path.join(config.BOOTSTRAP_RESULTS_DIR, 'bootstrap_test_set_metrics_all_iterations.csv'))

# Plot distributions
plot_metric_distributions(metrics_df, plot_graphs=False)
# Out:
# Bootstrap Performance Metrics on Test Set:
#       Metric      Mean   Std Dev  95% CI Lower  95% CI Upper
# 0   Accuracy  0.884935  0.004175      0.876435      0.892721
# 1  Precision  0.888828  0.005805      0.877121      0.899689
# 2     Recall  0.880470  0.005743      0.869577      0.892277
# 3   F1-score  0.884613  0.004309      0.876109      0.892676
# 4    AUC-ROC  0.950008  0.002739      0.944562      0.955370
# 5     AUC-PR  0.953236  0.002847      0.947439      0.958644
