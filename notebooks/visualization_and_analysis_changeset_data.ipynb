# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1. Data Loading Visualization

# %%
import pandas as pd

from config import VISUALIZATION_DATA_PATH

# Load saved data sample from data loading step
data_loading_sample_path = VISUALIZATION_DATA_PATH['data_loading']
changeset_df = pd.read_parquet(data_loading_sample_path)

# print("Summary statistics of the dataset:")
# display(changeset_df.describe())

print("Distribution of target variable (vandalism):")
vandalism_counts = changeset_df['label'].value_counts()
display(vandalism_counts)

# Visualize the data
print("\nSample of loaded changeset data:")
display(changeset_df.head())

# Plot distribution of target variable
# vandalism_counts.plot(kind='bar', title='Vandalism Distribution', xlabel='Vandalism', ylabel='Count')
# Out:
# Distribution of target variable (vandalism):
# label
# False    58
# True     42
# Name: count, dtype: int64
# Sample of loaded changeset data:
#    changeset_id                created_at                 closed_at  \
# 0      19739784 2014-01-01 00:16:15+00:00 2014-01-01 00:16:17+00:00
# 1      19739822 2014-01-01 00:21:49+00:00 2014-01-01 00:21:51+00:00
# 2      19740673 2014-01-01 03:44:23+00:00 2014-01-01 03:44:25+00:00
# 3      19740747 2014-01-01 04:12:07+00:00 2014-01-01 04:12:09+00:00
# 4      19740824 2014-01-01 04:36:01+00:00 2014-01-01 04:36:08+00:00
#
#           user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  bryanpiczon   688302            3  10.376628  123.400400  10.498390
# 1  bryanpiczon   688302           13  10.376457  123.633181  10.390640
# 2  bryanpiczon   688302           21   9.749016  124.004176  10.410474
# 3  bryanpiczon   688302           10   9.783770  125.079765  10.766378
# 4  bryanpiczon   688302           13   9.796782  125.077679  10.712891
#
#       max_lon  ... label no_nodes  no_ways  no_relations  no_creates  \
# 0  123.635174  ...  True        1        2             0           1
# 1  123.640732  ...  True       10        3             0          12
# 2  125.187905  ...  True       17        4             0          21
# 3  125.929561  ...  True        8        2             0           8
# 4  125.838949  ...  True       11        2             0          12
#
#    no_modifications  no_deletions     uid       account_created  changes_count
# 0                 2             0  688302  2012-05-24T12:27:56Z              0
# 1                 1             0  688302  2012-05-24T12:27:56Z              0
# 2                 0             0  688302  2012-05-24T12:27:56Z              0
# 3                 2             0  688302  2012-05-24T12:27:56Z              0
# 4                 1             0  688302  2012-05-24T12:27:56Z              0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 2. Feature Engineering Visualization

# %%
# Load saved data sample from feature engineering step
feature_engineering_sample_path = VISUALIZATION_DATA_PATH['feature_engineering']
features_df = pd.read_parquet(feature_engineering_sample_path)

# print("Summary statistics of the features:")
# display(features_df.describe())
# print("")

# Visualize the features
print("Sample of extracted features:")
display(features_df.head())
# Out:
# Sample of extracted features:
#    changeset_id                created_at                 closed_at  \
# 0      19739784 2014-01-01 00:16:15+00:00 2014-01-01 00:16:17+00:00
# 1      19739822 2014-01-01 00:21:49+00:00 2014-01-01 00:21:51+00:00
# 2      19740673 2014-01-01 03:44:23+00:00 2014-01-01 03:44:25+00:00
# 3      19740747 2014-01-01 04:12:07+00:00 2014-01-01 04:12:09+00:00
# 4      19740824 2014-01-01 04:36:01+00:00 2014-01-01 04:36:08+00:00
#
#           user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  bryanpiczon   688302            3  10.376628  123.400400  10.498390
# 1  bryanpiczon   688302           13  10.376457  123.633181  10.390640
# 2  bryanpiczon   688302           21   9.749016  124.004176  10.410474
# 3  bryanpiczon   688302           10   9.783770  125.079765  10.766378
# 4  bryanpiczon   688302           13   9.796782  125.077679  10.712891
#
#       max_lon  ... no_creates no_modifications  no_deletions     uid  \
# 0  123.635174  ...          1                2             0  688302
# 1  123.640732  ...         12                1             0  688302
# 2  125.187905  ...         21                0             0  688302
# 3  125.929561  ...          8                2             0  688302
# 4  125.838949  ...         12                1             0  688302
#
#         account_created  changes_count  centroid_x  centroid_y  \
# 0  2012-05-24T12:27:56Z              0  123.517787   10.437509
# 1  2012-05-24T12:27:56Z              0  123.636956   10.383549
# 2  2012-05-24T12:27:56Z              0  124.596040   10.079745
# 3  2012-05-24T12:27:56Z              0  125.504663   10.275074
# 4  2012-05-24T12:27:56Z              0  125.458314   10.254837
#
#    changeset_comment_length              date_created
# 0                         4 2014-01-01 00:16:15+00:00
# 1                         4 2014-01-01 00:21:49+00:00
# 2                         4 2014-01-01 03:44:23+00:00
# 3                         4 2014-01-01 04:12:07+00:00
# 4                         4 2014-01-01 04:36:01+00:00
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 3. Preprocessing Visualization

# %%
# Load saved data samples from preprocessing step
preprocessing_X_sample_path = VISUALIZATION_DATA_PATH['preprocessing_X']
preprocessing_y_sample_path = VISUALIZATION_DATA_PATH['preprocessing_y']

X_encoded = pd.read_parquet(preprocessing_X_sample_path)
y = pd.read_parquet(preprocessing_y_sample_path)

# Visualize the preprocessed features
print("Sample of preprocessed feature data (X):")
display(X_encoded.head())

print("\nSample of preprocessed target data (y):")
display(y.head())

# Check class imbalance in target data
class_distribution = y.value_counts()
print("\nDistribution of target variable (preprocessed):")
display(class_distribution)

# Plot class distribution
# class_distribution.plot(kind='bar', title='Class Distribution', xlabel='Class', ylabel='Count')
#
# Out:
# Sample of preprocessed feature data (X):
#       closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  1.388535e+09   688302            3  10.376628  123.400400  10.498390
# 1  1.388536e+09   688302           13  10.376457  123.633181  10.390640
# 2  1.388548e+09   688302           21   9.749016  124.004176  10.410474
# 3  1.388550e+09   688302           10   9.783770  125.079765  10.766378
# 4  1.388551e+09   688302           13   9.796782  125.077679  10.712891
#
#       max_lon  no_nodes  no_ways  no_relations  ...  created_by_iD 1.3.4  \
# 0  123.635174         1        2             0  ...                 True
# 1  123.640732        10        3             0  ...                 True
# 2  125.187905        17        4             0  ...                 True
# 3  125.929561         8        2             0  ...                 True
# 4  125.838949        11        2             0  ...                 True
#
#    created_by_iD 1.3.5  created_by_iD 1.3.6  created_by_iD 1.3.7  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    created_by_iD 1.3.8  created_by_iD 1.3.9  created_by_iD 1.7.0  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#   created_by_iD 1.7.1  created_by_iD 1.7.2  created_by_rosemary v0.3.12
# 0               False                False                        False
# 1               False                False                        False
# 2               False                False                        False
# 3               False                False                        False
# 4               False                False                        False
#
# [5 rows x 159 columns]
# Sample of preprocessed target data (y):
#    vandalism
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# Distribution of target variable (preprocessed):
# vandalism
# False        58
# True         42
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Data Splitting Visualization

# %%
# Load saved data sample from data splitting step
X_train = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_train'])
X_val = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_val'])
X_test = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_test'])

# Assuming y_train, y_val, y_test are not saved; recreate splits using loaded samples if needed
# Visualize data splits
print("Sample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Print the shapes of train, validation, and test datasets (if shapes were logged previously)
print("\nShapes of datasets:")
shapes = {
    'X_train': X_train.shape,
    'X_val': X_val.shape,  # Uncomment if loaded
    'X_test': X_test.shape,  # Uncomment if loaded
    # 'y_train': y_train.shape,  # Uncomment if loaded
    # 'y_val': y_val.shape,  # Uncomment if loaded
    # 'y_test': y_test.shape,  # Uncomment if loaded
}
shapes_df = pd.DataFrame.from_dict(shapes, orient='index', columns=['Rows', 'Columns'])
display(shapes_df)
# Out:
# Sample of X_train:
# Empty DataFrame
# Columns: [closed_at, user_id, num_changes, min_lat, min_lon, max_lat, max_lon, no_nodes, no_ways, no_relations, no_creates, no_modifications, no_deletions, account_created, centroid_x, centroid_y, changeset_comment_length, created_by_Go Map!! 1.1, created_by_Go Map!! 1.3.1, created_by_JOSM/1.5 (5267 en), created_by_JOSM/1.5 (5485 fr), created_by_JOSM/1.5 (5697 en), created_by_JOSM/1.5 (5697 fr), created_by_JOSM/1.5 (5836 en) Windows 7, created_by_JOSM/1.5 (5932 en) Windows 7 64-Bit, created_by_JOSM/1.5 (5990 ca), created_by_JOSM/1.5 (5990 en), created_by_JOSM/1.5 (6060 ru), created_by_JOSM/1.5 (6115 de), created_by_JOSM/1.5 (6115 en), created_by_JOSM/1.5 (6115 en_GB), created_by_JOSM/1.5 (6238 en_GB), created_by_JOSM/1.5 (6238 fr), created_by_JOSM/1.5 (6238 it), created_by_JOSM/1.5 (6238 pl), created_by_JOSM/1.5 (6269 SVN en), created_by_JOSM/1.5 (6388 de), created_by_JOSM/1.5 (6388 es), created_by_JOSM/1.5 (6502 SVN en_GB), created_by_JOSM/1.5 (6502 de), created_by_JOSM/1.5 (6502 en), created_by_JOSM/1.5 (6502 en_AU), created_by_JOSM/1.5 (6502 en_GB), created_by_JOSM/1.5 (6502 fi), created_by_JOSM/1.5 (6502 fr), created_by_JOSM/1.5 (6502 pl), created_by_JOSM/1.5 (6502 ru), created_by_JOSM/1.5 (6509 SVN en), created_by_JOSM/1.5 (6679 en), created_by_JOSM/1.5 (6679 fr), created_by_JOSM/1.5 (6767 de), created_by_JOSM/1.5 (6767 en), created_by_JOSM/1.5 (6767 en_GB), created_by_JOSM/1.5 (6767 es), created_by_JOSM/1.5 (6767 fi), created_by_JOSM/1.5 (6767 fr), created_by_JOSM/1.5 (6767 it), created_by_JOSM/1.5 (6767 nl), created_by_JOSM/1.5 (6798 en), created_by_JOSM/1.5 (6875 en), created_by_JOSM/1.5 (6891 de), created_by_JOSM/1.5 (6891 en), created_by_JOSM/1.5 (6891 en_GB), created_by_JOSM/1.5 (6891 fr), created_by_JOSM/1.5 (6891 it), created_by_JOSM/1.5 (6891 ja), created_by_JOSM/1.5 (6891 nl), created_by_JOSM/1.5 (6891 pt_BR), created_by_JOSM/1.5 (6891 ru), created_by_JOSM/1.5 (6891 zh_CN), created_by_JOSM/1.5 (6906 pt_BR), created_by_JOSM/1.5 (6909 en), created_by_JOSM/1.5 (6920 en_GB), created_by_JOSM/1.5 (6934 de), created_by_JOSM/1.5 (6942 SVN en_GB), created_by_JOSM/1.5 (6950 de), created_by_JOSM/1.5 (6950 en), created_by_JOSM/1.5 (6950 en_GB), created_by_JOSM/1.5 (6950 fr), created_by_JOSM/1.5 (6950 it), created_by_JOSM/1.5 (6950 nl), created_by_JOSM/1.5 (6950 pl), created_by_JOSM/1.5 (6950 ru), created_by_JOSM/1.5 (6999 de), created_by_JOSM/1.5 (7000 fr), created_by_JOSM/1.5 (7000 pt_BR), created_by_JOSM/1.5 (7182 de), created_by_JOSM/1.5 (7347 fr), created_by_JOSM/1.5 (7480 en), created_by_JOSM/1.5 (7588 de), created_by_JOSM/1.5 (7643 SVN en), created_by_JOSM/1.5 (7643 de), created_by_JOSM/1.5 (7643 en), created_by_JOSM/1.5 (7906 de), created_by_JOSM/1.5 (7906 en), created_by_JOSM/1.5 (7995 en), created_by_JOSM/1.5 (7995 ru), created_by_JOSM/1.5 (8109 de), created_by_JOSM/1.5 (8109 en), created_by_JOSM/1.5 (8109 en_AU), ...]
# Index: []
#
# [0 rows x 158 columns]
# Sample of X_val:
#         closed_at  user_id  num_changes    min_lat    min_lon    max_lat  \
# 447  1.427401e+09   634789          155  45.550374   5.933208  45.566724
# 448  1.427400e+09  2418039          164  53.719206   9.659136  53.721108
# 449  1.427419e+09  2778740            2  40.631338 -73.816443  40.662819
# 450  1.427440e+09  2787389            1  26.349619  83.091482  26.349619
# 451  1.427440e+09  2787389           19  26.332968  83.073135  26.353106
#
#        max_lon  no_nodes  no_ways  no_relations  ...  created_by_iD 1.3.4  \
# 447   5.949046       145       10             0  ...                False
# 448   9.666583       126       38             0  ...                False
# 449 -73.734267         0        2             0  ...                False
# 450  83.091482         1        0             0  ...                False
# 451  83.093920        17        2             0  ...                False
#
#      created_by_iD 1.3.5  created_by_iD 1.3.6  created_by_iD 1.3.7  \
# 447                False                False                False
# 448                False                False                False
# 449                False                False                False
# 450                False                False                False
# 451                False                False                False
#
#      created_by_iD 1.3.8  created_by_iD 1.3.9  created_by_iD 1.7.0  \
# 447                False                False                False
# 448                False                False                 True
# 449                False                False                False
# 450                False                False                 True
# 451                False                False                 True
#
#      created_by_iD 1.7.1  created_by_iD 1.7.2  created_by_rosemary v0.3.12
# 447                False                False                        False
# 448                False                False                        False
# 449                False                False                        False
# 450                False                False                        False
# 451                False                False                        False
#
# [5 rows x 158 columns]
# Sample of X_test:
# Empty DataFrame
# Columns: [closed_at, user_id, num_changes, min_lat, min_lon, max_lat, max_lon, no_nodes, no_ways, no_relations, no_creates, no_modifications, no_deletions, account_created, centroid_x, centroid_y, changeset_comment_length, created_by_Go Map!! 1.1, created_by_Go Map!! 1.3.1, created_by_JOSM/1.5 (5267 en), created_by_JOSM/1.5 (5485 fr), created_by_JOSM/1.5 (5697 en), created_by_JOSM/1.5 (5697 fr), created_by_JOSM/1.5 (5836 en) Windows 7, created_by_JOSM/1.5 (5932 en) Windows 7 64-Bit, created_by_JOSM/1.5 (5990 ca), created_by_JOSM/1.5 (5990 en), created_by_JOSM/1.5 (6060 ru), created_by_JOSM/1.5 (6115 de), created_by_JOSM/1.5 (6115 en), created_by_JOSM/1.5 (6115 en_GB), created_by_JOSM/1.5 (6238 en_GB), created_by_JOSM/1.5 (6238 fr), created_by_JOSM/1.5 (6238 it), created_by_JOSM/1.5 (6238 pl), created_by_JOSM/1.5 (6269 SVN en), created_by_JOSM/1.5 (6388 de), created_by_JOSM/1.5 (6388 es), created_by_JOSM/1.5 (6502 SVN en_GB), created_by_JOSM/1.5 (6502 de), created_by_JOSM/1.5 (6502 en), created_by_JOSM/1.5 (6502 en_AU), created_by_JOSM/1.5 (6502 en_GB), created_by_JOSM/1.5 (6502 fi), created_by_JOSM/1.5 (6502 fr), created_by_JOSM/1.5 (6502 pl), created_by_JOSM/1.5 (6502 ru), created_by_JOSM/1.5 (6509 SVN en), created_by_JOSM/1.5 (6679 en), created_by_JOSM/1.5 (6679 fr), created_by_JOSM/1.5 (6767 de), created_by_JOSM/1.5 (6767 en), created_by_JOSM/1.5 (6767 en_GB), created_by_JOSM/1.5 (6767 es), created_by_JOSM/1.5 (6767 fi), created_by_JOSM/1.5 (6767 fr), created_by_JOSM/1.5 (6767 it), created_by_JOSM/1.5 (6767 nl), created_by_JOSM/1.5 (6798 en), created_by_JOSM/1.5 (6875 en), created_by_JOSM/1.5 (6891 de), created_by_JOSM/1.5 (6891 en), created_by_JOSM/1.5 (6891 en_GB), created_by_JOSM/1.5 (6891 fr), created_by_JOSM/1.5 (6891 it), created_by_JOSM/1.5 (6891 ja), created_by_JOSM/1.5 (6891 nl), created_by_JOSM/1.5 (6891 pt_BR), created_by_JOSM/1.5 (6891 ru), created_by_JOSM/1.5 (6891 zh_CN), created_by_JOSM/1.5 (6906 pt_BR), created_by_JOSM/1.5 (6909 en), created_by_JOSM/1.5 (6920 en_GB), created_by_JOSM/1.5 (6934 de), created_by_JOSM/1.5 (6942 SVN en_GB), created_by_JOSM/1.5 (6950 de), created_by_JOSM/1.5 (6950 en), created_by_JOSM/1.5 (6950 en_GB), created_by_JOSM/1.5 (6950 fr), created_by_JOSM/1.5 (6950 it), created_by_JOSM/1.5 (6950 nl), created_by_JOSM/1.5 (6950 pl), created_by_JOSM/1.5 (6950 ru), created_by_JOSM/1.5 (6999 de), created_by_JOSM/1.5 (7000 fr), created_by_JOSM/1.5 (7000 pt_BR), created_by_JOSM/1.5 (7182 de), created_by_JOSM/1.5 (7347 fr), created_by_JOSM/1.5 (7480 en), created_by_JOSM/1.5 (7588 de), created_by_JOSM/1.5 (7643 SVN en), created_by_JOSM/1.5 (7643 de), created_by_JOSM/1.5 (7643 en), created_by_JOSM/1.5 (7906 de), created_by_JOSM/1.5 (7906 en), created_by_JOSM/1.5 (7995 en), created_by_JOSM/1.5 (7995 ru), created_by_JOSM/1.5 (8109 de), created_by_JOSM/1.5 (8109 en), created_by_JOSM/1.5 (8109 en_AU), ...]
# Index: []
#
# [0 rows x 158 columns]
# Shapes of datasets:
#          Rows  Columns
# X_train     0      158
# X_val     100      158
# X_test      0      158

# %% [markdown]
# ### 5. Clustering Visualization

# %%
# Notebook Code to Visualize Clustering
from src.clustering import load_clustered_data

X_train, X_val, X_test = load_clustered_data()

print("Data after adding clustering labels:")
print("\nSample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Visualize the clustering results
# visualize_clustering()
# Out:
# 2024-11-27 02:39:14 - INFO - clustering.py -- Clustered data loaded successfully.
# Data after adding clustering labels:
#
# Sample of X_train:
#         closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 319  1.394919e+09  1799232          173  -3.727336  -79.617667  -0.030343
# 85   1.389958e+09  1841157           15  23.467608  120.434533  23.469308
# 778  1.430749e+09  2875760            2  40.951517   24.072577  40.951716
# 249  1.393424e+09    37069          581 -21.044036   55.699754 -21.023088
# 893  1.432267e+09  2928141           11  19.052048   72.907787  19.052798
#
#         max_lon  no_nodes  no_ways  no_relations  ...  created_by_iD 1.3.5  \
# 319  -78.419906       141       32             0  ...                False
# 85   120.435817        14        1             0  ...                 True
# 778   24.072875         1        1             0  ...                False
# 249   55.722919       512       66             3  ...                False
# 893   72.909325         7        4             0  ...                False
#
#      created_by_iD 1.3.6  created_by_iD 1.3.7  created_by_iD 1.3.8  \
# 319                False                False                False
# 85                 False                False                False
# 778                False                False                False
# 249                False                False                False
# 893                False                False                False
#
#      created_by_iD 1.3.9  created_by_iD 1.7.0  created_by_iD 1.7.1  \
# 319                False                False                False
# 85                 False                False                False
# 778                False                False                False
# 249                False                False                False
# 893                False                False                False
#
#      created_by_iD 1.7.2  created_by_rosemary v0.3.12  cluster_label
# 319                False                        False             68
# 85                 False                        False             55
# 778                 True                        False             21
# 249                False                        False             29
# 893                 True                        False             42
#
# [5 rows x 159 columns]
# Sample of X_val:
#         closed_at  user_id  num_changes    min_lat    min_lon    max_lat  \
# 723  1.430298e+09  1098648            7  49.567304  10.967010  49.567400
# 311  1.394774e+09  1979159           31  56.662391  35.661445  56.666160
# 307  1.394587e+09  1892868            1 -17.604688 -45.193363 -17.597228
# 947  1.433005e+09  2096672           13  44.655916  16.734330  44.688534
# 539  1.428155e+09   695797            1  54.774826   9.436587  54.774826
#
#        max_lon  no_nodes  no_ways  no_relations  ...  created_by_iD 1.3.5  \
# 723  10.967115         6        1             0  ...                False
# 311  35.678467        29        2             0  ...                False
# 307 -45.165657         0        1             0  ...                False
# 947  16.760072        12        1             0  ...                False
# 539   9.436587         1        0             0  ...                False
#
#      created_by_iD 1.3.6  created_by_iD 1.3.7  created_by_iD 1.3.8  \
# 723                False                False                False
# 311                False                 True                False
# 307                False                 True                False
# 947                False                False                False
# 539                False                False                False
#
#      created_by_iD 1.3.9  created_by_iD 1.7.0  created_by_iD 1.7.1  \
# 723                False                False                False
# 311                False                False                False
# 307                False                False                False
# 947                False                False                False
# 539                False                 True                False
#
#      created_by_iD 1.7.2  created_by_rosemary v0.3.12  cluster_label
# 723                False                        False             82
# 311                False                        False             37
# 307                False                        False             18
# 947                 True                        False             28
# 539                False                        False             25
#
# [5 rows x 159 columns]
# Sample of X_test:
#         closed_at  user_id  num_changes    min_lat     min_lon    max_lat  \
# 234  1.392962e+09   803459            1  51.155291   13.675560  51.155545
# 684  1.429980e+09  2858266           11  46.466140   17.642030  46.469082
# 570  1.428617e+09  2778620          200  19.495542  -98.182773  19.847837
# 544  1.428215e+09   360544           39 -32.039629  116.068141 -31.935541
# 193  1.392240e+09  1494110            9  38.852770  -94.815950  38.855221
#
#         max_lon  no_nodes  no_ways  no_relations  ...  created_by_iD 1.3.5  \
# 234   13.676248         0        1             0  ...                False
# 684   17.653626         4        7             0  ...                False
# 570  -98.010325        92      108             0  ...                False
# 544  116.160642        37        2             0  ...                False
# 193  -94.813136         6        3             0  ...                False
#
#      created_by_iD 1.3.6  created_by_iD 1.3.7  created_by_iD 1.3.8  \
# 234                False                False                False
# 684                False                False                False
# 570                False                False                False
# 544                False                False                False
# 193                False                False                False
#
#      created_by_iD 1.3.9  created_by_iD 1.7.0  created_by_iD 1.7.1  \
# 234                False                False                False
# 684                False                False                False
# 570                False                False                False
# 544                False                 True                False
# 193                False                False                False
#
#      created_by_iD 1.7.2  created_by_rosemary v0.3.12  cluster_label
# 234                False                        False             56
# 684                False                        False             28
# 570                False                        False              0
# 544                False                        False             33
# 193                False                        False             27
#
# [5 rows x 159 columns]

# %% [markdown]
# ### 6. Model Evaluation Visualization

# %%
# Import evaluation functions
from evaluation import plot_confusion_matrix, plot_roc_pr_curves

# Display the confusion matrix
print("Confusion Matrix:")
plot_confusion_matrix()

# Plot ROC and Precision-Recall curves
print("\nROC and Precision-Recall Curves:")
plot_roc_pr_curves()
# Out:
# Confusion Matrix:
# ROC and Precision-Recall Curves:

# %% [markdown]
# ### 7. Bootstrapping Visualization

# %%
import config
import os
# In your Jupyter Notebook
import pandas as pd
from src.bootstrap_evaluation import plot_metric_distributions

# Load bootstrap metrics
metrics_df = pd.read_csv(os.path.join(config.BOOTSTRAP_RESULTS_DIR, 'bootstrap_test_set_metrics_all_iterations.csv'))

# Plot distributions
plot_metric_distributions(metrics_df, plot_graphs=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 8
#       5 from src.bootstrap_evaluation import plot_metric_distributions
#       7 # Load bootstrap metrics
# ----> 8 metrics_df = pd.read_csv(os.path.join(config.BOOTSTRAP_RESULTS_DIR, 'bootstrap_test_set_metrics_all_iterations.csv'))
#      10 # Plot distributions
#      11 plot_metric_distributions(metrics_df, plot_graphs=False)
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\PycharmProjects\\vandalism_detection_osm\\data\\changeset_data\\processed\\temporal\\bootstrap_results\\bootstrap_test_set_metrics_all_iterations.csv'
