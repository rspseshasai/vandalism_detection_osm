# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1. Data Loading Visualization

# %%
import pandas as pd

from config import VISUALIZATION_DATA_PATH

# Load saved data sample from data loading step
data_loading_sample_path = VISUALIZATION_DATA_PATH['data_loading']
changeset_df = pd.read_parquet(data_loading_sample_path)

# print("Summary statistics of the dataset:")
# display(changeset_df.describe())

print("Distribution of target variable (vandalism):")
vandalism_counts = changeset_df['label'].value_counts()
display(vandalism_counts)

# Visualize the data
print("\nSample of loaded changeset data:")
display(changeset_df.head())

# Plot distribution of target variable
# vandalism_counts.plot(kind='bar', title='Vandalism Distribution', xlabel='Vandalism', ylabel='Count')
# Out:
# Distribution of target variable (vandalism):
# label
# False    58
# True     42
# Name: count, dtype: int64
# Sample of loaded changeset data:
#    changeset_id                created_at                 closed_at  \
# 0      19739784 2014-01-01 00:16:15+00:00 2014-01-01 00:16:17+00:00
# 1      19739822 2014-01-01 00:21:49+00:00 2014-01-01 00:21:51+00:00
# 2      19740673 2014-01-01 03:44:23+00:00 2014-01-01 03:44:25+00:00
# 3      19740747 2014-01-01 04:12:07+00:00 2014-01-01 04:12:09+00:00
# 4      19740824 2014-01-01 04:36:01+00:00 2014-01-01 04:36:08+00:00
#
#           user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 0  bryanpiczon   688302            3  10.376628  123.400400  10.498390
# 1  bryanpiczon   688302           13  10.376457  123.633181  10.390640
# 2  bryanpiczon   688302           21   9.749016  124.004176  10.410474
# 3  bryanpiczon   688302           10   9.783770  125.079765  10.766378
# ...

# %% [markdown]
# ### 2. Feature Engineering Visualization

# %%
# Load saved data sample from feature engineering step
feature_engineering_sample_path = VISUALIZATION_DATA_PATH['feature_engineering']
features_df = pd.read_parquet(feature_engineering_sample_path)

# print("Summary statistics of the features:")
# display(features_df.describe())
# print("")

# Visualize the features
print("Sample of extracted features:")
display(features_df.head())
# Out:
# Sample of extracted features:
#     changeset_id                created_at                 closed_at  \
# 28      19826013 2014-01-05 16:07:42+00:00 2014-01-05 17:07:42+00:00
# 37      19857662 2014-01-07 06:23:33+00:00 2014-01-07 06:23:39+00:00
# 38      19858959 2014-01-07 08:44:35+00:00 2014-01-07 08:44:46+00:00
# 51      19924396 2014-01-10 20:32:11+00:00 2014-01-10 20:32:12+00:00
# 67      19990467 2014-01-14 13:09:02+00:00 2014-01-14 13:09:14+00:00
#
#             user  user_id  num_changes    min_lat     min_lon    max_lat  \
# 28   dr_grijando   548834            1  43.296113   -1.865174  43.296647
# 37         Phays   600592           30  -8.300026  118.403496  -8.299330
# 38        letihu  1787357          226  53.063336    8.803147  53.078123
# 51  marcocaiella  1868649            5  42.907668   12.342737  42.907897
# 67  Павел_Сасово   591962           89  54.341430   41.959570  54.350690
#
#        max_lon  ... no_relations no_creates  no_modifications  no_deletions  \
# ...

# %% [markdown]
# ### 3. Preprocessing Visualization

# %%
# Load saved data samples from preprocessing step
preprocessing_X_sample_path = VISUALIZATION_DATA_PATH['preprocessing_X']
preprocessing_y_sample_path = VISUALIZATION_DATA_PATH['preprocessing_y']

X_encoded = pd.read_parquet(preprocessing_X_sample_path)
y = pd.read_parquet(preprocessing_y_sample_path)

# Visualize the preprocessed features
print("Sample of preprocessed feature data (X):")
display(X_encoded.head())

print("\nSample of preprocessed target data (y):")
display(y.head())

# Check class imbalance in target data
class_distribution = y.value_counts()
print("\nDistribution of target variable (preprocessed):")
display(class_distribution)

# Plot class distribution
# class_distribution.plot(kind='bar', title='Class Distribution', xlabel='Class', ylabel='Count')
#
# Out:
# Sample of preprocessed feature data (X):
#     changeset_id     closed_at  user_id  num_changes    min_lat     min_lon  \
# 28      19826013  1.388942e+09   548834            1  43.296113   -1.865174
# 37      19857662  1.389076e+09   600592           30  -8.300026  118.403496
# 38      19858959  1.389084e+09  1787357          226  53.063336    8.803147
# 51      19924396  1.389386e+09  1868649            5  42.907668   12.342737
# 67      19990467  1.389705e+09   591962           89  54.341430   41.959570
#
#       max_lat     max_lon  no_nodes  no_ways  ...  created_by_iD 2.6.1  \
# 28  43.296647   -1.863377         0        1  ...                False
# 37  -8.299330  118.404500        27        3  ...                False
# 38  53.078123    8.896301       171       55  ...                False
# 51  42.907897   12.343035         4        1  ...                False
# 67  54.350690   41.971045         0       89  ...                False
#
# ...

# %% [markdown]
# ### 4. Data Splitting Visualization

# %%
# Load saved data sample from data splitting step
X_train = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_train'])
X_val = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_val'])
X_test = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_test'])

# Assuming y_train, y_val, y_test are not saved; recreate splits using loaded samples if needed
# Visualize data splits
print("Sample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Print the shapes of train, validation, and test datasets (if shapes were logged previously)
print("\nShapes of datasets:")
shapes = {
    'X_train': X_train.shape,
    'X_val': X_val.shape,  # Uncomment if loaded
    'X_test': X_test.shape,  # Uncomment if loaded
    # 'y_train': y_train.shape,  # Uncomment if loaded
    # 'y_val': y_val.shape,  # Uncomment if loaded
    # 'y_test': y_test.shape,  # Uncomment if loaded
}
shapes_df = pd.DataFrame.from_dict(shapes, orient='index', columns=['Rows', 'Columns'])
display(shapes_df)
# Out:
# Sample of X_train:
#        changeset_id     closed_at  user_id  num_changes    min_lat    min_lon  \
# 8954       54526455  1.512957e+09  6310073            5  38.564243 -75.119921
# 6329       48595159  1.494514e+09  2485308            2  48.690947  11.804075
# 3049       39453685  1.463759e+09  3987481            1 -17.121928  36.263185
# 11542      59868544  1.529052e+09  6069065           39  50.420454  30.467873
# 13540      66422487  1.547809e+09  9196089            1  41.461712   2.206817
#
#          max_lat    max_lon  no_nodes  no_ways  ...  created_by_iD 2.6.1  \
# 8954   38.564517 -75.119574         4        1  ...                False
# 6329   48.691003  11.804603         1        1  ...                False
# 3049  -17.121928  36.263185         1        0  ...                False
# 11542  50.424294  30.474018         5        9  ...                False
# 13540  41.462136   2.207887         0        1  ...                False
#
# ...

# %% [markdown]
# ### 5. Clustering Visualization

# %%
# Notebook Code to Visualize Clustering
from src.clustering import load_clustered_data

X_train, X_val, X_test = load_clustered_data()

print("Data after adding clustering labels:")
print("\nSample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Visualize the clustering results
# visualize_clustering()
# Out:
# 2024-12-01 00:28:03 - INFO - clustering.py -- Clustered data loaded successfully.
# Data after adding clustering labels:
#
# Sample of X_train:
#        changeset_id     closed_at  user_id  num_changes    min_lat    min_lon  \
# 8954       54526455  1.512957e+09  6310073            5  38.564243 -75.119921
# 6329       48595159  1.494514e+09  2485308            2  48.690947  11.804075
# 3049       39453685  1.463759e+09  3987481            1 -17.121928  36.263185
# 11542      59868544  1.529052e+09  6069065           39  50.420454  30.467873
# 13540      66422487  1.547809e+09  9196089            1  41.461712   2.206817
#
#          max_lat    max_lon  no_nodes  no_ways  ...  created_by_iD 2.7.0  \
# 8954   38.564517 -75.119574         4        1  ...                False
# 6329   48.691003  11.804603         1        1  ...                False
# 3049  -17.121928  36.263185         1        0  ...                False
# ...

# %% [markdown]
# ### 6. Model Evaluation Visualization

# %%
# Import evaluation functions
from evaluation import plot_confusion_matrix, plot_roc_pr_curves

# Display the confusion matrix
print("Confusion Matrix:")
plot_confusion_matrix()

# Plot ROC and Precision-Recall curves
print("\nROC and Precision-Recall Curves:")
plot_roc_pr_curves()
# Out:
# Confusion Matrix:
# ROC and Precision-Recall Curves:

# %% [markdown]
# ### 7. Bootstrapping Visualization

# %%
import config
import os
# In your Jupyter Notebook
import pandas as pd
from src.bootstrap_evaluation import plot_metric_distributions

# Load bootstrap metrics
metrics_df = pd.read_csv(os.path.join(config.BOOTSTRAP_RESULTS_DIR, 'bootstrap_test_set_metrics_all_iterations.csv'))

# Plot distributions
plot_metric_distributions(metrics_df, plot_graphs=False)
# Out:
# Bootstrap Performance Metrics on Test Set:
#       Metric      Mean   Std Dev  95% CI Lower  95% CI Upper
# 0   Accuracy  0.863719  0.018207      0.828125      0.896875
# 1  Precision  0.855939  0.034921      0.782148      0.918376
# 2     Recall  0.754488  0.038219      0.680664      0.826096
# 3   F1-score  0.801310  0.028616      0.745082      0.852811
# 4    AUC-ROC  0.923322  0.014680      0.891898      0.950942
# 5     AUC-PR  0.899268  0.021047      0.854417      0.934597

# %% [markdown]
# ## Hyper Classifier model for Changeset data

# %% [markdown]
# #### 1. Imports and Setup

# %%
from config import HYPER_VISUALIZATION_DIR
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define the paths (update these as needed)
AGGREGATED_FEATURES_PATH = os.path.join(HYPER_VISUALIZATION_DIR, 'aggregated_features_sample.parquet')
EVALUATION_RESULTS_PATH = os.path.join(HYPER_VISUALIZATION_DIR, 'evaluation_results.parquet')
CONFUSION_MATRIX_PATH = os.path.join(HYPER_VISUALIZATION_DIR, 'confusion_matrix.npy')

# Helper function to set consistent plot styles
def set_plot_style():
    sns.set(style="whitegrid")
    plt.rcParams.update({"font.size": 12})

# %% [markdown]
# #### 2. Visualize Aggregated Features

# %%
# Load aggregated features
aggregated_features = pd.read_parquet(AGGREGATED_FEATURES_PATH)

# Display the first few rows
print("Aggregated Features Sample:")
aggregated_features.head()
# Out:
# Aggregated Features Sample:
#    changeset_id  num_contributions  mean_prediction  median_prediction  \
# 0      19826013                  1         0.003762           0.003762
# 1      19857662                  8         0.122685           0.119308
# 2      19858959                 82         0.006790           0.006079
# 3      19924396                  1         0.047656           0.047656
# 4      19990467                 89         0.001997           0.002167
#
#    std_prediction  min_prediction  max_prediction  quantile_25  quantile_75  \
# 0        0.000000        0.003762        0.003762     0.003762     0.003762
# 1        0.019668        0.103534        0.155935     0.103534     0.138165
# 2        0.003659        0.003296        0.031796     0.004701     0.008000
# 3        0.000000        0.047656        0.047656     0.047656     0.047656
# 4        0.000287        0.001251        0.002544     0.001832     0.002167
#
# ...

# %%
# Plot distributions of key features
set_plot_style()

# Number of contributions
plt.figure(figsize=(8, 5))
sns.histplot(aggregated_features['num_contributions'], bins=30, kde=True, color='blue')
plt.title('Distribution of Number of Contributions per Changeset')
plt.xlabel('Number of Contributions')
plt.ylabel('Frequency')
plt.show()

# Mean prediction
plt.figure(figsize=(8, 5))
sns.histplot(aggregated_features['mean_prediction'], bins=30, kde=True, color='green')
plt.title('Distribution of Mean Predictions')
plt.xlabel('Mean Prediction')
plt.ylabel('Frequency')
plt.show()

# Standard deviation of predictions
plt.figure(figsize=(8, 5))
sns.histplot(aggregated_features['std_prediction'], bins=30, kde=True, color='orange')
plt.title('Distribution of Standard Deviation of Predictions')
plt.xlabel('Standard Deviation')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### 3. Visualize Evaluation Results

# %%
# Load evaluation results
evaluation_results = pd.read_parquet(EVALUATION_RESULTS_PATH)

# Display the first few rows
print("Evaluation Results Sample:")
evaluation_results.head()
# Out:
# Evaluation Results Sample:
#    changeset_id  y_true  y_pred_hyper  y_pred    y_prob  y_prob_hyper
# 0      58556915   False             0       0  0.008672      0.008672
# 1      45483694   False             0       0  0.002931      0.002931
# 2      36144221    True             1       1  0.996671      0.996671
# 3      59573882   False             0       0  0.004906      0.004906
# 4      75760224    True             1       1  0.996671      0.996671

# %%
# Load confusion matrix
confusion_matrix = np.load(CONFUSION_MATRIX_PATH)

# Plot confusion matrix
set_plot_style()

plt.figure(figsize=(6, 5))
sns.heatmap(
    confusion_matrix, annot=True, fmt='d', cmap='Blues',
    xticklabels=['Non-Vandalism', 'Vandalism'],
    yticklabels=['Non-Vandalism', 'Vandalism']
)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Calculate and display key metrics from evaluation results
accuracy = (evaluation_results['y_true'] == evaluation_results['y_pred']).mean()
precision = evaluation_results.query("y_pred == 1 & y_true == 1").shape[0] / evaluation_results.query("y_pred == 1").shape[0]
recall = evaluation_results.query("y_pred == 1 & y_true == 1").shape[0] / evaluation_results.query("y_true == 1").shape[0]
f1_score = 2 * (precision * recall) / (precision + recall)

print("Evaluation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Evaluation Metrics:
# Accuracy: 0.9625
# Precision: 0.9796
# Recall: 0.9412
# F1 Score: 0.9600

# %% [markdown]
# #### 4. Visualize ROC and PR Curves

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Calculate ROC Curve
fpr, tpr, _ = roc_curve(evaluation_results['y_true'], evaluation_results['y_prob'])

# Plot ROC Curve
plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(evaluation_results['y_true'], evaluation_results['y_prob']):.4f}")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

# Calculate Precision-Recall Curve
precision, recall, _ = precision_recall_curve(evaluation_results['y_true'], evaluation_results['y_prob'])

# Plot Precision-Recall Curve
plt.figure(figsize=(8, 5))
plt.plot(recall, precision, label=f"Avg Precision = {average_precision_score(evaluation_results['y_true'], evaluation_results['y_prob']):.4f}")
plt.title("Precision-Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend(loc="lower left")
plt.grid()
plt.show()

# %% [markdown]
# ## Ensemble model

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the path to the ensemble directory
ensemble_dir = os.path.join('path_to_visualization_data', 'ensemble')

# Load the evaluation metrics from JSON file
metrics_path = os.path.join(ensemble_dir, 'evaluation_metrics.json')
with open(metrics_path, 'r') as f:
    metrics = json.load(f)

# Convert the metrics dictionary to a DataFrame
metrics_df = pd.DataFrame.from_dict(metrics, orient='index')

# Display the metrics DataFrame
metrics_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 12
#      10 # Load the evaluation metrics from JSON file
#      11 metrics_path = os.path.join(ensemble_dir, 'evaluation_metrics.json')
# ---> 12 with open(metrics_path, 'r') as f:
#      13     metrics = json.load(f)
#      15 # Convert the metrics dictionary to a DataFrame
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
# Extract evaluation metrics for plotting
models = metrics_df.index.tolist()
accuracy_list = metrics_df['accuracy'].tolist()
precision_list = metrics_df['precision'].tolist()
recall_list = metrics_df['recall'].tolist()
f1_score_list = metrics_df['f1_score'].tolist()
auc_roc_list = metrics_df['auc_roc'].tolist()

# Create a new DataFrame for plotting
plot_data = pd.DataFrame({
    'Model': models,
    'Accuracy': accuracy_list,
    'Precision': precision_list,
    'Recall': recall_list,
    'F1 Score': f1_score_list,
    'AUC-ROC': auc_roc_list
})

# %%
# Set plot style
sns.set(style='whitegrid', font_scale=1.2)

# Plot AUC-ROC scores comparison
plt.figure(figsize=(8, 6))
sns.barplot(x='Model', y='AUC-ROC', data=plot_data)
plt.title('Comparison of AUC-ROC Scores')
plt.ylabel('AUC-ROC Score')
plt.xlabel('Model')
plt.ylim(0, 1)
plt.show()

# %%
# Plot Accuracy comparison
plt.figure(figsize=(8, 6))
sns.barplot(x='Model', y='Accuracy', data=plot_data)
plt.title('Comparison of Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Model')
plt.ylim(0, 1)
plt.show()

# %%
# Plot Precision comparison
plt.figure(figsize=(8, 6))
sns.barplot(x='Model', y='Precision', data=plot_data)
plt.title('Comparison of Precision')
plt.ylabel('Precision')
plt.xlabel('Model')
plt.ylim(0, 1)
plt.show()

# Plot Recall comparison
plt.figure(figsize=(8, 6))
sns.barplot(x='Model', y='Recall', data=plot_data)
plt.title('Comparison of Recall')
plt.ylabel('Recall')
plt.xlabel('Model')
plt.ylim(0, 1)
plt.show()

# Plot F1 Score comparison
plt.figure(figsize=(8, 6))
sns.barplot(x='Model', y='F1 Score', data=plot_data)
plt.title('Comparison of F1 Score')
plt.ylabel('F1 Score')
plt.xlabel('Model')
plt.ylim(0, 1)
plt.show()

# %%
for model_name in metrics.keys():
    print(f"\n{model_name} Confusion Matrix:")
    conf_matrix = metrics[model_name]['confusion_matrix']
    print(conf_matrix)
    
    print(f"\n{model_name} Classification Report:")
    report = metrics[model_name]['classification_report']
    report_df = pd.DataFrame(report).transpose()
    display(report_df)

# %%
# Load the combined evaluation results
ensemble_results_path = os.path.join(ensemble_dir, 'ensemble_evaluation.parquet')
ensemble_results = pd.read_parquet(ensemble_results_path)

# Display the first few rows of the combined data set
print("Combined Data Set Table:")
ensemble_results.head()

# %%
import pandas as pd
import os

# Define the path to the ensemble directory
ensemble_dir = os.path.join('path_to_visualization_data', 'ensemble')

# Load the comparison metrics
metrics_table_path = os.path.join(ensemble_dir, 'comparison_metrics.csv')
metrics_df = pd.read_csv(metrics_table_path, index_col=0)

# Display the metrics DataFrame
print("Comparison of Evaluation Metrics:")
display(metrics_df)
