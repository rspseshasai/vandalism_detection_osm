# %%
# %load_ext autoreload
# %autoreload 2
PYTHONUNBUFFERED=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1. Data Loading Visualization

# %%
import pandas as pd

from config import VISUALIZATION_DATA_PATH

# Load saved data sample from data loading step
data_loading_sample_path = VISUALIZATION_DATA_PATH['data_loading']
contributions_df = pd.read_parquet(data_loading_sample_path)

# print("Summary statistics of the dataset:")
# display(contributions_df.describe())

print("Distribution of target variable (vandalism):")
vandalism_counts = contributions_df['vandalism'].value_counts()
display(vandalism_counts)

# Visualize the data
print("\nSample of loaded contributions data:")
display(contributions_df.head())

# Plot distribution of target variable
# vandalism_counts.plot(kind='bar', title='Vandalism Distribution', xlabel='Vandalism', ylabel='Count')
# Out:
# Distribution of target variable (vandalism):
# vandalism
# False    67
# True     33
# Name: count, dtype: int64
# Sample of loaded contributions data:
#    user_id          valid_from   valid_to osm_type         osm_id  \
# 0  2377515 2014-10-06 23:59:31 2525-01-01      way  way/306274324
# 1  2377515 2014-10-06 23:59:31 2525-01-01      way  way/306274325
# 2  6335199 2017-12-19 01:47:30 2525-01-01      way  way/508546101
# 3  5193146 2018-01-27 20:06:23 2525-01-01      way  way/470020391
# 4  3149129 2015-12-11 19:43:11 2525-01-01      way  way/383928694
#
#    osm_version contrib_type members   status  \
# 0            2      DELETED    None  deleted
# 1            2      DELETED    None  deleted
# 2            3      DELETED    None  deleted
# 3            6      DELETED    None  deleted
# 4            2      DELETED    None  deleted
#
#                                            changeset  ...       xmax  \
# 0  {'editor': 'iD 1.5.4', 'hashtags': [], 'id': 2...  ... -62.976084
# 1  {'editor': 'iD 1.5.4', 'hashtags': [], 'id': 2...  ... -62.956141
# 2  {'editor': 'iD 2.5.1', 'hashtags': [], 'id': 5...  ... -90.207543
# 3  {'editor': 'JOSM/1.5 (13265 es)', 'hashtags': ...  ...  -0.898112
# 4  {'editor': 'JOSM/1.5 (8969 pt_BR)', 'hashtags'...  ... -34.881410
#
#         ymin       ymax                                           centroid  \
# 0 -84.906653 -84.906087  {'x': -63.00606307447101, 'y': -84.9061737972215}
# 1 -84.906658 -84.905873  {'x': -63.02389380624011, 'y': -84.90541275705...
# 2  38.520176  38.525163  {'x': -90.20805486920308, 'y': 38.52402543148942}
# 3  41.655704  41.659127  {'x': -0.9040472730470975, 'y': 41.65753419208...
# 4  -8.043162  -8.043102  {'x': -34.88146198953866, 'y': -8.043138886726...
#
#    quadkey_z10               h3_r5    geometry_type geometry_valid  \
# 0   2323223122  603185502329241599  InvalidGeometry          False
# 1   2323223122  603185502329241599  InvalidGeometry          False
# 2   0231113113  599651674105053183  InvalidGeometry          False
# 3   0313333303  599989239207165951  InvalidGeometry          False
# 4   2110031320  601257186567389183  InvalidGeometry          False
#
#                                             geometry vandalism
# 0  POLYGON ((-62.9969414 -84.90658619999999, -62....      True
# 1  POLYGON ((-62.9729527 -84.9058725, -62.9757816...      True
# 2  POLYGON ((-90.20804009999999 38.5251629, -90.2...      True
# 3  POLYGON ((-0.9073251 41.658674399999995, -0.90...      True
# 4  POLYGON ((-34.8814103 -8.0431621, -34.8815028 ...      True
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 2. Feature Engineering Visualization

# %%
# Load saved data sample from feature engineering step
feature_engineering_sample_path = VISUALIZATION_DATA_PATH['feature_engineering']
features_df = pd.read_parquet(feature_engineering_sample_path)

# print("Summary statistics of the features:")
# display(features_df.describe())
# print("")

# Visualize the features
print("Sample of extracted features:")
display(features_df.head())
# Out:
# Sample of extracted features:
#     user_id  edit_frequency_7d  edit_frequency_14d  edit_frequency_30d  \
# 29  2773196                0.0                 0.0                 0.0
# 89   549284                0.0                 0.0                 0.0
# 90   549284                0.0                 0.0                 0.0
# 91   549284                0.0                 0.0                 0.0
# 92   549284                0.0                 0.0                 0.0
#
#     edit_frequency_60d  edit_frequency_180d  edit_frequency_365d  \
# 29                 0.0                  0.0                  0.0
# 89                 0.0                  0.0                  0.0
# 90                 0.0                  0.0                  0.0
# 91                 0.0                  0.0                  0.0
# 92                 0.0                  0.0                  0.0
#
#     edit_frequency_all editor_used  area_delta  ...  emergency  geological  \
# 29            0.027854        JOSM      -15231  ...          0           0
# 89            0.027854        JOSM           0  ...          0           0
# 90            0.027854        JOSM           0  ...          0           0
# 91            0.027854        JOSM           0  ...          0           0
# 92            0.027854        JOSM           0  ...          0           0
#
#     healthcare highway  historic  landuse  leisure  man_made  military  \
# 29           0       0         0        0        1         0         0
# 89           0       0         0        0        0         0         0
# 90           0       0         0        0        0         0         0
# 91           0       0         0        0        0         0         0
# 92           0       0         0        0        0         0         0
#
#     vandalism
# 29       True
# 89      False
# 90      False
# 91      False
# 92      False
#
# [5 rows x 122 columns]

# %% [markdown]
# ### 3. Preprocessing Visualization

# %%
# Load saved data samples from preprocessing step
preprocessing_X_sample_path = VISUALIZATION_DATA_PATH['preprocessing_X']
preprocessing_y_sample_path = VISUALIZATION_DATA_PATH['preprocessing_y']

X_encoded = pd.read_parquet(preprocessing_X_sample_path)
y = pd.read_parquet(preprocessing_y_sample_path)

# Visualize the preprocessed features
print("Sample of preprocessed feature data (X):")
display(X_encoded.head())

print("\nSample of preprocessed target data (y):")
display(y.head())

# Check class imbalance in target data
class_distribution = y.value_counts()
print("\nDistribution of target variable (preprocessed):")
display(class_distribution)

# Plot class distribution
# class_distribution.plot(kind='bar', title='Class Distribution', xlabel='Class', ylabel='Count')
#
# Out:
# Sample of preprocessed feature data (X):
#    user_id  edit_frequency_7d  edit_frequency_14d  edit_frequency_30d  \
# 0  2554323                0.0                 0.0                 0.0
# 1   179778                0.0                 0.0                 0.0
# 2  8259661                0.0                 0.0                 0.0
# 3   179778                0.0                 0.0                 0.0
# 4   179778                0.0                 0.0                 0.0
#
#    edit_frequency_60d  edit_frequency_180d  edit_frequency_365d  \
# 0                 0.0             0.000000             0.000000
# 1                 0.0             0.000000             0.000000
# 2                 0.0             0.933333             0.460274
# 3                 0.0             0.000000             0.000000
# 4                 0.0             0.000000             0.000000
#
#    edit_frequency_all  area_delta  length_delta  ...  \
# 0            0.003653           0             0  ...
# 1            6.875799           1             0  ...
# 2            0.076712           0             0  ...
# 3            6.875799           0             0  ...
# 4            6.875799           0             0  ...
#
#    geometry_type_LineString  geometry_type_Point  geometry_type_Polygon  \
# 0                      True                False                  False
# 1                     False                False                   True
# 2                     False                False                   True
# 3                     False                False                   True
# 4                     False                False                   True
#
#    edit_frequency_of_osm_element_frequently_edited  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    edit_frequency_of_osm_element_moderately_edited  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    edit_frequency_of_osm_element_rarely_edited  time_of_day_afternoon  \
# 0                                         True                  False
# 1                                         True                  False
# 2                                         True                  False
# 3                                         True                  False
# 4                                         True                  False
#
#    time_of_day_evening  time_of_day_morning  time_of_day_night
# 0                False                 True              False
# 1                False                False               True
# 2                False                False               True
# 3                False                False               True
# 4                False                False               True
#
# [5 rows x 243 columns]
# Sample of preprocessed target data (y):
#    vandalism
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# Distribution of target variable (preprocessed):
# vandalism
# True         76
# False        24
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Data Splitting Visualization

# %%
# Load saved data sample from data splitting step
X_train = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_train'])
X_val = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_val'])
X_test = pd.read_parquet(VISUALIZATION_DATA_PATH['data_splitting_X_test'])

# Assuming y_train, y_val, y_test are not saved; recreate splits using loaded samples if needed
# Visualize data splits
print("Sample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Print the shapes of train, validation, and test datasets (if shapes were logged previously)
print("\nShapes of datasets:")
shapes = {
    'X_train': X_train.shape,
    'X_val': X_val.shape,  # Uncomment if loaded
    'X_test': X_test.shape,  # Uncomment if loaded
    # 'y_train': y_train.shape,  # Uncomment if loaded
    # 'y_val': y_val.shape,  # Uncomment if loaded
    # 'y_test': y_test.shape,  # Uncomment if loaded
}
shapes_df = pd.DataFrame.from_dict(shapes, orient='index', columns=['Rows', 'Columns'])
display(shapes_df)
# Out:
# Sample of X_train:
#         user_id  edit_frequency_7d  edit_frequency_14d  edit_frequency_30d  \
# 11538  10403957                0.0                 0.0           28.033333
# 12650   6224152                0.0                 0.0            0.000000
# 11052    179778                0.0                 0.0            0.000000
# 3034     179778                0.0                 0.0            0.000000
# 2613    2169558                0.0                 0.0            0.000000
#
#        edit_frequency_60d  edit_frequency_180d  edit_frequency_365d  \
# 11538           43.083333            14.361111             7.082192
# 12650            0.000000             0.000000             0.000000
# 11052            0.000000             0.000000             0.000000
# 3034             0.000000             0.000000             0.000000
# 2613             0.000000             0.000000             0.000000
#
#        edit_frequency_all  area_delta  length_delta  ...  \
# 11538            1.180365          74             0  ...
# 12650            0.029224          26             0  ...
# 11052            6.875799           0             0  ...
# 3034             6.875799           0             0  ...
# 2613             0.238356           0             0  ...
#
#        geometry_type_LineString  geometry_type_Point  geometry_type_Polygon  \
# 11538                     False                False                   True
# 12650                     False                False                   True
# 11052                     False                False                   True
# 3034                      False                False                   True
# 2613                      False                False                   True
#
#        edit_frequency_of_osm_element_frequently_edited  \
# 11538                                            False
# 12650                                            False
# 11052                                            False
# 3034                                             False
# 2613                                             False
#
#        edit_frequency_of_osm_element_moderately_edited  \
# 11538                                            False
# 12650                                            False
# 11052                                            False
# 3034                                             False
# 2613                                             False
#
#        edit_frequency_of_osm_element_rarely_edited  time_of_day_afternoon  \
# 11538                                         True                   True
# 12650                                         True                   True
# 11052                                         True                  False
# 3034                                          True                  False
# 2613                                          True                   True
#
#        time_of_day_evening  time_of_day_morning  time_of_day_night
# 11538                False                False              False
# 12650                False                False              False
# 11052                False                False               True
# 3034                 False                False               True
# 2613                 False                False              False
#
# [5 rows x 243 columns]
# Sample of X_val:
#        user_id  edit_frequency_7d  edit_frequency_14d  edit_frequency_30d  \
# 16178   553736                0.0                 0.0                 0.0
# 3584   6964739                0.0                 0.0                 0.0
# 2791   9625392                0.0                 0.0                 0.0
# 19565  7139860                0.0                 0.0                 0.0
# 24350  7678930                0.0                 0.0                 0.0
#
#        edit_frequency_60d  edit_frequency_180d  edit_frequency_365d  \
# 16178            0.000000             0.000000             0.000000
# 3584             0.000000             0.000000             0.000000
# 2791             1.533333             0.511111             0.252055
# 19565            0.000000             0.205556             0.386301
# 24350            0.000000             0.000000             0.000000
#
#        edit_frequency_all  area_delta  length_delta  ...  \
# 16178            0.015068           0             0  ...
# 3584             0.053881         178             0  ...
# 2791             0.042009           0            -5  ...
# 19565            0.351598           0           175  ...
# 24350            0.002740           0             0  ...
#
#        geometry_type_LineString  geometry_type_Point  geometry_type_Polygon  \
# 16178                     False                 True                  False
# 3584                      False                False                   True
# 2791                       True                False                  False
# 19565                      True                False                  False
# 24350                     False                 True                  False
#
#        edit_frequency_of_osm_element_frequently_edited  \
# 16178                                            False
# 3584                                             False
# 2791                                             False
# 19565                                            False
# 24350                                            False
#
#        edit_frequency_of_osm_element_moderately_edited  \
# 16178                                            False
# 3584                                             False
# 2791                                             False
# 19565                                            False
# 24350                                            False
#
#        edit_frequency_of_osm_element_rarely_edited  time_of_day_afternoon  \
# 16178                                         True                  False
# 3584                                          True                  False
# 2791                                          True                  False
# 19565                                         True                  False
# 24350                                         True                   True
#
#        time_of_day_evening  time_of_day_morning  time_of_day_night
# 16178                False                 True              False
# 3584                  True                False              False
# 2791                 False                 True              False
# 19565                 True                False              False
# 24350                False                False              False
#
# [5 rows x 243 columns]
# Sample of X_test:
#         user_id  edit_frequency_7d  edit_frequency_14d  edit_frequency_30d  \
# 26936   7446645                0.0                 0.0                 0.0
# 14987    179778                0.0                 0.0                 0.0
# 9605     179778                0.0                 0.0                 0.0
# 2555   10161696                0.0                 0.0                 0.0
# 26836    179778                0.0                 0.0                 0.0
#
#        edit_frequency_60d  edit_frequency_180d  edit_frequency_365d  \
# 26936                 0.0             0.000000             0.000000
# 14987                 0.0             0.000000             0.000000
# 9605                  0.0             0.000000             0.000000
# 2555                  0.0             0.083333             0.041096
# 26836                 0.0             0.000000             0.000000
#
#        edit_frequency_all  area_delta  length_delta  ...  \
# 26936            2.407763           0            -3  ...
# 14987            6.875799           0             0  ...
# 9605             6.875799           0             0  ...
# 2555             0.006849         -23             0  ...
# 26836            6.875799           0             0  ...
#
#        geometry_type_LineString  geometry_type_Point  geometry_type_Polygon  \
# 26936                      True                False                  False
# 14987                     False                False                   True
# 9605                      False                False                   True
# 2555                      False                False                   True
# 26836                     False                False                   True
#
#        edit_frequency_of_osm_element_frequently_edited  \
# 26936                                            False
# 14987                                            False
# 9605                                             False
# 2555                                             False
# 26836                                            False
#
#        edit_frequency_of_osm_element_moderately_edited  \
# 26936                                            False
# 14987                                            False
# 9605                                             False
# 2555                                             False
# 26836                                            False
#
#        edit_frequency_of_osm_element_rarely_edited  time_of_day_afternoon  \
# 26936                                         True                  False
# 14987                                         True                  False
# 9605                                          True                  False
# 2555                                          True                  False
# 26836                                         True                  False
#
#        time_of_day_evening  time_of_day_morning  time_of_day_night
# 26936                False                 True              False
# 14987                False                False               True
# 9605                 False                False               True
# 2555                 False                False               True
# 26836                False                False               True
#
# [5 rows x 243 columns]
# Shapes of datasets:
#          Rows  Columns
# X_train   100      243
# X_val     100      243
# X_test    100      243

# %% [markdown]
# ### 5. Clustering Visualization

# %%
# Notebook Code to Visualize Clustering
from src.clustering import load_clustered_data

X_train, X_val, X_test = load_clustered_data()

print("Data after adding clustering labels:")
print("\nSample of X_train:")
display(X_train.head())

print("\nSample of X_val:")
display(X_val.head())

print("\nSample of X_test:")
display(X_test.head())

# Visualize the clustering results
# visualize_clustering()
# Out:
# 2024-12-03 02:45:11 - INFO - clustering.py -- Clustered data loaded successfully.
# Data after adding clustering labels:
#
# Sample of X_train:
#        changeset_id     closed_at  user_id  num_changes    min_lat  \
# 17235      25985115  1.412955e+09  2237750           54  39.738040
# 9215       54952525  1.514373e+09  6521966          187   3.491123
# 5712       46663373  1.488920e+09  5446083           52  53.594951
# 4062       42567255  1.475342e+09   152305           79  57.409308
# 17300      26281898  1.414085e+09  2211570           38  50.713197
#
#           min_lon    max_lat     max_lon  no_nodes  no_ways  ...  \
# 17235 -105.028256  39.746821 -105.016724        53        1  ...
# 9215    98.694209   3.532013   98.718448       156       31  ...
# 5712    -6.525176  53.630010   -6.128029        42       10  ...
# 4062    21.659728  57.926717   25.435421        59       20  ...
# 17300   12.364905  50.720085   12.372441        33        5  ...
#
#        created_by_iD 2.7.0  created_by_iD 2.7.1  created_by_iD 2.8.0  \
# 17235                False                False                False
# 9215                 False                False                False
# 5712                 False                False                False
# 4062                 False                False                False
# 17300                False                False                False
#
#        created_by_iD 2.8.1  created_by_iD 2.8.2  created_by_iD 2.9.0  \
# 17235                False                False                False
# 9215                 False                False                False
# 5712                 False                False                False
# 4062                 False                False                False
# 17300                False                False                False
#
#        created_by_iD 2.9.1  created_by_iD 2.9.2  created_by_upload.py v. 1  \
# 17235                False                False                      False
# 9215                 False                False                      False
# 5712                 False                False                      False
# 4062                 False                False                      False
# 17300                False                False                      False
#
#        cluster_label
# 17235             32
# 9215              73
# 5712              94
# 4062              76
# 17300             71
#
# [5 rows x 300 columns]
# Sample of X_val:
#        changeset_id     closed_at   user_id  num_changes    min_lat  \
# 4806       44958182  1.483721e+09   1772800           14  36.261040
# 15657      71829434  1.562089e+09  10082622          104  21.355656
# 1002       31884776  1.433976e+09   2977954            4 -32.923137
# 4982       45483694  1.485365e+09   5035303            6  51.808880
# 10529      57147573  1.520952e+09   7771501            6  35.533055
#
#           min_lon    max_lat     max_lon  no_nodes  no_ways  ...  \
# 4806     2.181707  36.265352    2.194007        12        2  ...
# 15657 -101.910086  21.360988 -101.898436        93       11  ...
# 1002   -60.740442 -32.922620  -60.739565         3        1  ...
# 4982    -2.284956  51.818708   -2.262697         4        2  ...
# 10529  -97.529698  35.537183  -97.524047         5        1  ...
#
#        created_by_iD 2.7.0  created_by_iD 2.7.1  created_by_iD 2.8.0  \
# 4806                 False                False                False
# 15657                False                False                False
# 1002                 False                False                False
# 4982                 False                False                False
# 10529                False                 True                False
#
#        created_by_iD 2.8.1  created_by_iD 2.8.2  created_by_iD 2.9.0  \
# 4806                 False                False                False
# 15657                False                False                False
# 1002                 False                False                False
# 4982                 False                False                False
# 10529                False                False                False
#
#        created_by_iD 2.9.1  created_by_iD 2.9.2  created_by_upload.py v. 1  \
# 4806                 False                False                      False
# 15657                False                False                      False
# 1002                 False                False                      False
# 4982                 False                False                      False
# 10529                False                False                      False
#
#        cluster_label
# 4806              77
# 15657              2
# 1002              14
# 4982              41
# 10529             85
#
# [5 rows x 300 columns]
# Sample of X_test:
#        changeset_id     closed_at  user_id  num_changes    min_lat    min_lon  \
# 12338      62489903  1.536674e+09  8808855            1  60.282245  25.135131
# 2380       37783019  1.457793e+09  3579556            1  44.560631  34.327272
# 3930       42304912  1.474394e+09  3104985            3  53.196912  29.222315
# 299        21037621  1.394502e+09   121756            9  39.044064 -94.612217
# 8124       52920362  1.507976e+09  6631989           10  45.649110  13.792913
#
#          max_lat    max_lon  no_nodes  no_ways  ...  created_by_iD 2.7.0  \
# 12338  60.284801  25.139135         0        1  ...                False
# 2380   44.560631  34.327272         1        0  ...                False
# 3930   53.198936  29.229479         0        3  ...                False
# 299    39.057433 -94.611792         6        3  ...                False
# 8124   45.651033  13.794226         6        4  ...                False
#
#        created_by_iD 2.7.1  created_by_iD 2.8.0  created_by_iD 2.8.1  \
# 12338                False                False                False
# 2380                 False                False                False
# 3930                 False                False                False
# 299                  False                False                False
# 8124                 False                False                False
#
#        created_by_iD 2.8.2  created_by_iD 2.9.0  created_by_iD 2.9.1  \
# 12338                False                False                False
# 2380                 False                False                False
# 3930                 False                False                False
# 299                  False                False                False
# 8124                 False                False                False
#
#        created_by_iD 2.9.2  created_by_upload.py v. 1  cluster_label
# 12338                False                      False             76
# 2380                 False                      False             60
# 3930                 False                      False             19
# 299                  False                      False              7
# 8124                 False                      False             33
#
# [5 rows x 300 columns]

# %% [markdown]
# ### 6. Model Evaluation Visualization

# %%
# Import evaluation functions
from evaluation import plot_confusion_matrix, plot_roc_pr_curves

# Display the confusion matrix
print("Confusion Matrix:")
plot_confusion_matrix('main')

# Plot ROC and Precision-Recall curves
print("\nROC and Precision-Recall Curves:")
plot_roc_pr_curves('main')
# Out:
# Confusion Matrix:
# ROC and Precision-Recall Curves:

# %% [markdown]
# ### 7. Bootstrapping Visualization

# %%
import config
import os
# In your Jupyter Notebook
import pandas as pd
from src.bootstrap_evaluation import plot_metric_distributions

# Load bootstrap metrics
metrics_df = pd.read_csv(os.path.join(config.BOOTSTRAP_RESULTS_DIR, 'bootstrap_test_set_metrics_all_iterations.csv'))

# Plot distributions
plot_metric_distributions(metrics_df, plot_graphs=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 8
#       5 from src.bootstrap_evaluation import plot_metric_distributions
#       7 # Load bootstrap metrics
# ----> 8 metrics_df = pd.read_csv(os.path.join(config.BOOTSTRAP_RESULTS_DIR, 'bootstrap_test_set_metrics_all_iterations.csv'))
#      10 # Plot distributions
#      11 plot_metric_distributions(metrics_df, plot_graphs=False)
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File D:\PycharmProjects\vandalism_detection_osm\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\PycharmProjects\\vandalism_detection_osm\\data\\contribution_data\\processed\\random\\bootstrap_results\\bootstrap_test_set_metrics_all_iterations.csv'

# %% [markdown]
# ### 8. Geographical Visualization

# %%
# In your Jupyter Notebook
import pandas as pd

# Continent Evaluation Results
continent_results_path = os.path.join(config.GEOGRAPHICAL_RESULTS_DIR, 'continent_evaluation_results.csv')
continent_stats_df = pd.read_csv(continent_results_path)
print("Statistics Table for Each Continent:")
display(continent_stats_df)

# Country Evaluation Results
country_results_path = os.path.join(config.GEOGRAPHICAL_RESULTS_DIR, 'country_evaluation_results.csv')
country_stats_df = pd.read_csv(country_results_path)
print("\nStatistics Table for Each Country:")
country_stats_df.head(20)
# Out:
# Statistics Table for Each Continent:
#   Continent Name  Total Samples  Total Correct Predictions  \
# 0         Africa            656                        655
# 1           Asia           1215                       1206
# 2         Europe           5130                       5120
# 3  North America            728                        725
# 4        Oceania             69                         69
# 5          Other            687                        687
# 6  South America            980                        979
#
#    Total Incorrect Predictions  True Positives (TP)  True Negatives (TN)  \
# 0                            1                  396                  259
# 1                            9                  481                  725
# 2                           10                 3820                 1300
# 3                            3                  371                  354
# 4                            0                   17                   52
# 5                            0                  619                   68
# 6                            1                  753                  226
#
#    False Positives (FP)  False Negatives (FN)  Accuracy  Precision    Recall  \
# 0                     0                     1  0.998476   1.000000  0.997481
# 1                     1                     8  0.992593   0.997925  0.983640
# 2                     2                     8  0.998051   0.999477  0.997910
# 3                     2                     1  0.995879   0.994638  0.997312
# 4                     0                     0  1.000000   1.000000  1.000000
# 5                     0                     0  1.000000   1.000000  1.000000
# 6                     1                     0  0.998980   0.998674  1.000000
#
#    F1-score   AUC-ROC    AUC-PR
# 0  0.998739  0.999912  0.999944
# 1  0.990731  0.999386  0.999237
# 2  0.998693  0.999977  0.999992
# 3  0.995973  0.999940  0.999942
# 4  1.000000  1.000000  1.000000
# 5  1.000000  1.000000  1.000000
# 6  0.999336  1.000000  1.000000
# Statistics Table for Each Country:
#    Country Name  Total Samples  Total Correct Predictions  \
# 0           AFG              3                          3
# 1           AGO              9                          9
# 2           ARE              7                          7
# 3           ARG             10                         10
# 4           ARM              1                          1
# 5           AUS             50                         50
# 6           AUT             46                         46
# 7           AZE              1                          1
# 8           BEL            128                        128
# 9           BGD             96                         96
# 10          BIH             52                         52
# 11          BLR             18                         17
# 12          BOL              9                          9
# 13          BRA            304                        303
# 14          BWA              1                          1
# 15          CAF              7                          7
# 16          CAN            181                        179
# 17          CHE             99                         99
# 18          CHL            584                        584
# 19          CHN             36                         33
#
#     Total Incorrect Predictions  True Positives (TP)  True Negatives (TN)  \
# 0                             0                    0                    3
# 1                             0                    0                    9
# 2                             0                    0                    7
# 3                             0                    2                    8
# 4                             0                    1                    0
# 5                             0                    0                   50
# 6                             0                   25                   21
# 7                             0                    1                    0
# 8                             0                   92                   36
# 9                             0                   84                   12
# 10                            0                    0                   52
# 11                            1                    0                   17
# 12                            0                    0                    9
# 13                            1                  144                  159
# 14                            0                    0                    1
# 15                            0                    0                    7
# 16                            2                    9                  170
# 17                            0                   96                    3
# 18                            0                  579                    5
# 19                            3                    1                   32
#
#     False Positives (FP)  False Negatives (FN)  Accuracy  Precision  Recall  \
# 0                      0                     0  1.000000   0.000000    0.00
# 1                      0                     0  1.000000   0.000000    0.00
# 2                      0                     0  1.000000   0.000000    0.00
# 3                      0                     0  1.000000   1.000000    1.00
# 4                      0                     0  1.000000   1.000000    1.00
# 5                      0                     0  1.000000   0.000000    0.00
# 6                      0                     0  1.000000   1.000000    1.00
# 7                      0                     0  1.000000   1.000000    1.00
# 8                      0                     0  1.000000   1.000000    1.00
# 9                      0                     0  1.000000   1.000000    1.00
# 10                     0                     0  1.000000   0.000000    0.00
# 11                     1                     0  0.944444   0.000000    0.00
# 12                     0                     0  1.000000   0.000000    0.00
# 13                     1                     0  0.996711   0.993103    1.00
# 14                     0                     0  1.000000   0.000000    0.00
# 15                     0                     0  1.000000   0.000000    0.00
# 16                     2                     0  0.988950   0.818182    1.00
# 17                     0                     0  1.000000   1.000000    1.00
# 18                     0                     0  1.000000   1.000000    1.00
# 19                     0                     3  0.916667   1.000000    0.25
#
#     F1-score                     AUC-ROC                      AUC-PR
# 0    0.00000  Not defined (single class)  Not defined (single class)
# 1    0.00000  Not defined (single class)  Not defined (single class)
# 2    0.00000  Not defined (single class)  Not defined (single class)
# 3    1.00000                         1.0                         1.0
# 4    1.00000  Not defined (single class)  Not defined (single class)
# 5    0.00000  Not defined (single class)  Not defined (single class)
# 6    1.00000                         1.0                         1.0
# 7    1.00000  Not defined (single class)  Not defined (single class)
# 8    1.00000                         1.0                         1.0
# 9    1.00000                         1.0                         1.0
# 10   0.00000  Not defined (single class)  Not defined (single class)
# 11   0.00000  Not defined (single class)  Not defined (single class)
# 12   0.00000  Not defined (single class)  Not defined (single class)
# 13   0.99654                         1.0          0.9999999999999998
# 14   0.00000  Not defined (single class)  Not defined (single class)
# 15   0.00000  Not defined (single class)  Not defined (single class)
# 16   0.90000                         1.0          1.0000000000000002
# 17   1.00000                         1.0                         1.0
# 18   1.00000                         1.0                         1.0
# 19   0.40000                         1.0                         1.0
